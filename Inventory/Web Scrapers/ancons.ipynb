# %%
from   bs4 import BeautifulSoup
import requests

# %%
content = requests.get(url = 'https://fancons.com/events/')
soup  = BeautifulSoup(content.content,'html.parser')
webpage_text = soup.get_text()

items = [i.strip() for i in webpage_text.split('\n') if i != '']

start_idx = items.index('Location')
end_idx   = items[start_idx + 1:].index('Location')
events    = items[start_idx + 1 : end_idx]
events
# Out:
# ['PrezCon 2025',
#  'February 17-23, 2025',
#  'DoubleTree by Hilton Hotel CharlottesvilleCharlottesville, VA',
#  'NordicFuzzCon 2025',
#  'February 19-23, 2025',
#  'Clarion Hotel & Congress Malmö LiveMalmö, Sweden',
#  'FurSquared 2025',
#  'February 20-23, 2025',
#  'Hilton Milwaukee City CenterMilwaukee, WI',
#  'GenghisCon 2025',
#  'February 20-23, 2025',
#  'Hyatt Regency Aurora-Denver Conference CenterDenver, CO',
#  'Total Confusion 2025',
#  'February 20-23, 2025',
#  'Best Western Royal Plaza Hotel and Trade CenterMarlborough, MA',
#  'Bangor Anime 2025',
#  'February 21-23, 2025',
#  'Cross Insurance CenterBangor, ME',
#  'Con Nooga 2025',
#  'February 21-23, 2025',
#  'Chattanooga Convention CenterChattanooga, TN',
#  'Days of the Dead Atlanta 2025',
#  'February 21-23, 2025',
#  'Courtland Grand HotelAtlanta, GA',
#  'Fan Expo Vancouver 2025',
#  'February 21-23, 2025',
#  'Vancouver Convention CentreVancouver, BC, Canada',
#  'Great Lakes Comic Convention 2025',
#  'February 21-23, 2025',
#  'Macomb Community College Sports And Expo CenterWarren, MI',
#  'London Anime & Gaming Con 2025',
#  'February 21-23, 2025',
#  'Novotel London WestLondon, UK',
#  'Mad Monster Party Carolina 2025',
#  'February 21-23, 2025',
#  'Embassy Suites by Hilton Charlotte Concord Golf Resort & SpaConcord, NC',
#  'Melbourne Furry Convention 2025',
#  'February 21-23, 2025',
#  'Novotel Melbourne PrestonPreston, Victoria, Australia',
#  'Santiago Anthro Fest 2025',
#  'February 21-23, 2025',
#  'Almacruz Hotel y Centro de ConvencionesSantiago, Chile',
#  'Animangapop Bristol 2025',
#  'February 22, 2025',
#  'Future Inn Bristol Cabot CircusBristol, UK',
#  'Milwaukee Comic Con 2025',
#  'February 22, 2025',
#  'Wisconsin State Fairgrounds Expo Hall CWest Allis, WI',
#  'MultiCon 2025',
#  'February 22, 2025',
#  'The Preserve LALos Angeles, CA',
#  'Oshawa ComiCon 2025',
#  'February 22, 2025',
#  'YWCA DurhamOshawa, ON, Canada',
#  'Tape Con 2025',
#  'February 22, 2025',
#  'Ozark Gateway Association of RealtorsJoplin, MO',
#  'Alaska ComiCon 2025',
#  'February 22-23, 2025',
#  'Carlson CenterFairbanks, AK',
#  'Brazoria County Comic Con 2025',
#  'February 22-23, 2025',
#  'Lake Jackson Civic CenterLake Jackson, TX',
#  'Brick Fest Live Mesa 2025',
#  'February 22-23, 2025',
#  'Arizona Athletic GroundsMesa, AZ',
#  'Bricktastic 2025',
#  'February 22-23, 2025',
#  'Manchester Central Convention ComplexManchester, UK',
#  'Dead of Winter Horror Festival 2025',
#  'February 22-23, 2025',
#  'Mechanics HallWorcester, MA',
#  'Goliathcon 2025',
#  'February 22-23, 2025',
#  'Central New York Family Sport CentreSyracuse, NY',
#  'IbashoCon 2025',
#  'February 22-23, 2025',
#  'Hilton Raleigh North HillsRaleigh, NC',
#  'Lubbock-Con 2025',
#  'February 22-23, 2025',
#  'Lubbock Memorial Civic CenterLubbock, TX',
#  'NEPA Comic-Con 2025',
#  'February 22-23, 2025',
#  'Moon Tavern & Entertainment ComplexScranton, PA',
#  'Texoma Comic Con 2025',
#  'February 22-23, 2025',
#  'Choctaw Event CenterDurant, OK',
#  'The Surrey Steampunk Convivial 2025',
#  'February 22-23, 2025',
#  'The StationEpsom, UK',
#  'Comic Book & Non-Sports Card Show 2025',
#  'February 23, 2025',
#  'Annandale Volunteer Fire DepartmentAnnandale, VA',
#  'Nerd Fest 2025',
#  'February 23, 2025',
#  'Holiday Inn Philadelphia South-SwedesboroSwedesboro, NJ',
#  'OwlCon 2025',
#  'February 23, 2025',
#  'Rice University, Ley Student CenterHouston, TX',
#  'Peterborough ComiCon 2025',
#  'February 23, 2025',
#  'Peterborough Curling ClubPeterborough, ON, Canada',
#  'Simi Valley Toy and Comic Fest 2025',
#  'February 23, 2025',
#  'Grand Vista HotelSimi Valley, CA',
#  'Star Trek: The Cruise 2025',
#  'February\xa023 - March\xa02, 2025',
#  "Royal Caribbean's Explorer of the SeasDeparting from Miami, FL",
#  'Gdakon 2025',
#  'February\xa026 - March\xa02, 2025',
#  'Novotel Gdansk MarinaGdańsk, Poland',
#  'SaltCON Spring 2025',
#  'February\xa027 - March\xa02, 2025',
#  'Davis Conference CenterLayton, UT',
#  'Colossalcon Cruise 2025',
#  'February\xa027 - March\xa03, 2025',
#  "Royal Caribbean's Voyager of the SeasDeparting from Cape Canaveral, FL",
#  'Evercon 2025',
#  'February\xa028 - March\xa01, 2025',
#  'Central Wisconsin Convention and Expo CenterRothschild, WI',
#  'Gamicon 2025',
#  'February\xa028 - March\xa02, 2025',
#  'Hyatt Regency Coralville Hotel & Conference CenterCoralville, IA',
#  'Horror Realm 2025',
#  'February\xa028 - March\xa02, 2025',
#  'Crowne Plaza Suites Pittsburgh SouthPittsburgh, PA',
#  'LANFest Chicago x Midwest Battlegrounds 2025',
#  'February\xa028 - March\xa02, 2025',
#  'Sheraton Lisle Naperville HotelLisle, IL',
#  'Lone Star Fur Con 2025',
#  'February\xa028 - March\xa02, 2025',
#  'Holiday Inn Austin MidtownAustin, TX',
#  'Nerdi Gras 2025',
#  'February\xa028 - March\xa02, 2025',
#  'Crowne Plaza Atlanta - MidtownAtlanta, GA',
#  'Cobourg ComiCon 2025',
#  'March 1, 2025',
#  'Cobourg Community CentreCobourg, ON, Canada',
#  'Marietta the Gathering 2025',
#  'March 1, 2025',
#  'Marietta SquareMarietta, GA',
#  'Orlando AnimeDay 2025',
#  'March 1, 2025',
#  'Sheraton Orlando North HotelMaitland, FL',
#  'Panama City Comics Mini Con 2025',
#  'March 1, 2025',
#  'Bay County FairgroundsPanama City, FL',
#  'StingrayCon 2025',
#  'March 1, 2025',
#  'Atlantic Coast High SchoolJacksonville, FL',
#  'WreckCon 2025',
#  'March 1, 2025',
#  'Georgia Tech Exhibition Hall and Instructional CenterAtlanta, GA',
#  'Bomb City Con 2025',
#  'March 1-2, 2025',
#  'Amarillo Civic Center ComplexAmarillo, TX',
#  'Brick Fest Live Novi, Michigan 2025',
#  'March 1-2, 2025',
#  'Suburban Collection ShowplaceNovi, MI',
#  'BrickUniverse Jacksonville 2025',
#  'March 1-2, 2025',
#  'Jacksonville FairgroundsJacksonville, FL',
#  'Collect-A-Con Los Angeles 2025',
#  'March 1-2, 2025',
#  'Los Angeles Convention CenterLos Angeles, CA',
#  'Columbia Anime & Video Game Expo 2025',
#  'March 1-2, 2025',
#  'Jamil Shrine TempleColumbia, SC',
#  'Comic Con Scotland Aberdeen 2025',
#  'March 1-2, 2025',
#  'P&J LiveAberdeen, UK',
#  'Evansville Horror Con 2025',
#  'March 1-2, 2025',
#  'Old National Events PlazaEvansville, IN',
#  'Happy Valley Comic & Collectibles Convention 2025',
#  'March 1-2, 2025',
#  'Nittany Valley Sports CentreState College, PA',
#  'New Jersey Horror Con and Film Festival 2025',
#  'March 1-2, 2025',
#  'New Jersey Convention and Exposition CenterEdison, NJ',
#  'QuadCon Davenport 2025',
#  'March 1-2, 2025',
#  'NorthPark MallDavenport, IA',
#  'UI-Con 2025',
#  'March 1-2, 2025',
#  'University of Illinois Urbana-Champaign, Illini UnionUrbana, IL',
#  'Vincon 2025',
#  'March 1-2, 2025',
#  'FoothillsFort Collins, CO',
#  'Zolocon 2025',
#  'March 1-2, 2025',
#  'Valley Forge Casino ResortKing of Prussia, PA',
#  'Furcamp 2025',
#  'March 1-4, 2025',
#  'Parque Estadual IntervalesRibeirão Grande, SP, Brazil',
#  'Belleville ComiCon 2025',
#  'March 2, 2025',
#  'Masonic TempleBelleville, ON, Canada',
#  'Buckeye Comic-Con 2025',
#  'March 2, 2025',
#  'Aladdin Shrine CenterGrove City, OH',
#  'Fayetteville Anime-Fest 2025',
#  'March 2, 2025',
#  'DoubleTree by Hilton Hotel FayettevilleFayetteville, NC',
#  'Otaku Link 2025',
#  'March 2, 2025',
#  'The Old Bell HotelDerby, UK',
#  'SW-FloridaCon 2025',
#  'March 2, 2025',
#  'DoubleTree by Hilton Fort Myers at Bell Tower ShopsFort Myers, FL',
#  'Dark Force Fest 2025',
#  'March 2-4, 2025',
#  'Sheraton Parsippany HotelParsippany-Troy Hills, NJ',
#  'JoCo Cruise 2025',
#  'March 2-9, 2025',
#  "Holland America's ms Nieuw AmsterdamDeparting from Fort Lauderdale, FL",
#  'Wisconsin Esports Summit 2025',
#  'March 3, 2025',
#  'UW-Milwaukee Panther ArenaMilwaukee, WI',
#  'King Con Cruise 2025',
#  'March 3-7, 2025',
#  "Royal Caribbean's Independence of the SeasDeparting from Miami, FL",
#  'Emerald City Comic Con 2025',
#  'March 6-9, 2025',
#  'Seattle Convention CenterSeattle, WA',
#  'Lexington Comic & Toy Convention 2025',
#  'March 6-9, 2025',
#  'Central Bank CenterLexington, KY',
#  'VancouFur 2025',
#  'March 6-9, 2025',
#  'Richmond Conference CentreRichmond, BC, Canada',
#  'Anime Milwaukee 2025',
#  'March 7-9, 2025',
#  'Baird Center / Hilton Milwaukee City CenterMilwaukee, WI',
#  'Banzaicon 2025',
#  'March 7-9, 2025',
#  'DoubleTree by Hilton Hotel Columbia, South CarolinaColumbia, SC',
#  'Bewhiskered 2025',
#  'March 7-9, 2025',
#  'Sheraton Imperial Hotel Raleigh-Durham Airport at Research Triangle ParkDurham, NC',
#  'DBZ Con Los Angeles 2025',
#  'March 7-9, 2025',
#  'DoubleTree by Hilton Hotel Los Angeles - RosemeadRosemead, CA',
#  "Fur the 'More 2025",
#  'March 7-9, 2025',
#  'Hilton Washington Dulles AirportHerndon, VA',
#  'Kikori Con 2025',
#  'March 7-9, 2025',
#  'Little America Hotel - FlagstaffFlagstaff, AZ',
#  'MinamiCon 2025',
#  'March 7-9, 2025',
#  'Novotel SouthamptonSouthampton, UK',
#  'NorthEast ComicCon & Collectibles Extravaganza 2025',
#  'March 7-9, 2025',
#  'Boxboro Regency Hotel & Conference CenterBoxborough, MA',
#  'SCG Con Charlotte 2025',
#  'March 7-9, 2025',
#  'Charlotte Convention CenterCharlotte, NC',
#  'TFcon Los Angeles 2025',
#  'March 7-9, 2025',
#  'Los Angeles Marriott Burbank AirportBurbank, CA',
#  'Erie Anime-Fest 2025',
#  'March 8, 2025',
#  'Quality Inn & Suites Conference Center Across from CasinoErie, PA',
#  'Hair of the Dragon 2025',
#  'March 8, 2025',
#  'Studio Space AtlantaAtlanta, GA',
#  'Local Play 2025',
#  'March 8, 2025',
#  'Marley Station MallGlen Burnie, MD',
#  'Pop Madness 2025',
#  'March 8, 2025',
#  'Central LibrarySan Antonio, TX',
#  'Wilkes Comic Con 2025',
#  'March 8, 2025',
#  'The Stone Family Center for Performing ArtsNorth Wilkesboro, NC',
#  'ACEcon 2025',
#  'March 8-9, 2025',
#  'Palm Harbor LibraryPalm Harbor, FL',
#  'Bristol Anime & Gaming Con 2025',
#  'March 8-9, 2025',
#  'Mercure Bristol Grand HotelBristol, UK',
#  'Colorado Cosmic Con 2025',
#  'March 8-9, 2025',
#  'Colorado Springs Event CenterColorado Springs, CO',
#  'Elite_Comics11 Expo 2025',
#  'March 8-9, 2025',
#  "St. John's University, Taffner Field HouseQueens, NY",
#  'FantastiCon Toledo 2025',
#  'March 8-9, 2025',
#  'Glass City CenterToledo, OH',
#  'Louisiana Comic Con 2025',
#  'March 8-9, 2025',
#  'Cajundome Convention CenterLafayette, LA',
#  'Midland Mall Comic Con 2025',
#  'March 8-9, 2025',
#  'Midland MallMidland, MI',
#  'Mississippi Anime Fest 2025',
#  'March 8-9, 2025',
#  'Mississippi Trademart CenterJackson, MS',
#  'QuadCon Madison 2025',
#  'March 8-9, 2025',
#  'East Towne MallMadison, WI',
#  'Raleigh Toy & Collectible Show 2025',
#  'March 8-9, 2025',
#  'Kerr Scott BuildingRaleigh, NC',
#  'St. Pete Comic Con 2025',
#  'March 8-9, 2025',
#  'The ColiseumSt. Petersburg, FL',
#  'Ajax ComiCon 2025',
#  'March 9, 2025',
#  'Ajax SportsplexAjax, ON, Canada',
#  'Clifton NJ Comic Book Expo 2025',
#  'March 9, 2025',
#  'Clifton Early Learning CenterClifton, NJ',
#  'Niagara Anime-Fest 2025',
#  'March 9, 2025',
#  'Sheraton Niagara FallsNiagara Falls, NY',
#  'Escape Winter Con 2025',
#  'March 12-16, 2025',
#  'DoubleTree by Hilton Hotel Orlando at SeaWorldOrlando, FL',
#  'All-Con 2025',
#  'March 13-16, 2025',
#  'Hilton Dallas Lincoln CentreDallas, TX',
#  'Huntsville Comic Con 2025',
#  'March 14-15, 2025',
#  'Lowe Mill ARTS & EntertainmentHuntsville, AL',
#  'Bourbon City Steam 2025',
#  'March 14-16, 2025',
#  'Holiday Inn Louisville East - HurstbourneLouisville, KY',
#  'Collective Con 2025',
#  'March 14-16, 2025',
#  'The Prime F. Osborn III Convention CenterJacksonville, FL',
#  'conAgeddon 2025',
#  'March 14-16, 2025',
#  'Boston Logan Airport HiltonBoston, MA',
#  'EvilleCon 2025',
#  'March 14-16, 2025',
#  'Old National Events PlazaEvansville, IN',
#  'Hauntlanta 2025',
#  'March 14-16, 2025',
#  'Lanier Islands Legacy LodgeBuford, GA',
#  'Indiana Comic Convention 2025',
#  'March 14-16, 2025',
#  'Indianapolis Convention CenterIndianapolis, IN',
#  'Kawaii Kon 2025',
#  'March 14-16, 2025',
#  'Hawaii Convention CenterHonolulu, HI',
#  'Milwaukee Horror Con 2025',
#  'March 14-16, 2025',
#  'Four Points by Sheraton Milwaukee AirportMilwaukee, WI',
#  'Monster-Mania Con 2025',
#  'March 14-16, 2025',
#  'DoubleTree by Hilton Cherry Hill PhiladelphiaCherry Hill, NJ',
#  'Permian Basin Comic Con 2025',
#  'March 14-16, 2025',
#  'Midland County Horseshoe ArenaMidland, TX',
#  'Toronto Comicon 2025',
#  'March 14-16, 2025',
#  'Metro Toronto Convention CentreToronto, ON, Canada',
#  'TsumiCon 2025',
#  'March 14-16, 2025',
#  'Alexis Park ResortLas Vegas, NV',
#  "Ve Neill's Vampire Weekend 2025",
#  'March 14-16, 2025',
#  'Marriott Convention CenterBurbank, CA',
#  'Calgary Comic Book Show 2025',
#  'March 15, 2025',
#  'Millican Ogden Community AssociationCalgary, AB, Canada',
#  'ClarksvilleCon 2025',
#  'March 15, 2025',
#  'Quality Inn Exit 4Clarksville, TN',
#  'Indie Comics Creator Con 2025',
#  'March 15, 2025',
#  'Southern Connecticut State University, Adanti Student CenterNew Haven, CT',
#  'Owen Sound ComiCon 2025',
#  'March 15, 2025',
#  'Royal Canadian Legion Memorial Branch 6Owen Sound, ON, Canada',
#  'Power Comicon 2025',
#  'March 15, 2025',
#  'Florence CenterFlorence, SC',
#  'Sunrise Comic Con 2025',
#  'March 15, 2025',
#  'Sunrise Civic CenterSunrise, FL',
#  'BrickUniverse Waco 2025',
#  'March 15-16, 2025',
#  'BASE at Extraco Events CenterWaco, TX',
#  'Brighton Anime & Gaming Con 2025',
#  'March 15-16, 2025',
#  'The Old Ship HotelBrighton, UK',
#  'Comic, Film & Manga Fest 2025',
#  'March 15-16, 2025',
#  'Ahoy RotterdamRotterdam, Netherlands',
#  'CT Gamer & Anime Con 2025',
#  'March 15-16, 2025',
#  'Mohegan SunUncasville, CT',
#  'Dublin Comic Con: Spring Edition 2025',
#  'March 15-16, 2025',
#  'The Convention Centre DublinDublin, Ireland',
#  'Kansas Comic Con 2025',
#  'March 15-16, 2025',
#  'Century II Performing Arts & Convention CenterWichita, KS',
#  'Paris Manga & Sci-Fi Show 2025',
#  'March 15-16, 2025',
#  'Paris Porte de VersaillesParis, France',
#  'Pop Culture Con 2025',
#  'March 15-16, 2025',
#  'Houston CityPlace Marriott at Springwoods VillageSpring, TX',
#  'QuadCon Omaha 2025',
#  'March 15-16, 2025',
#  'Oak View MallOmaha, NE',
#  'San Diego Rocket Con 2025',
#  'March 15-16, 2025',
#  'Del Mar FairgroundsDel Mar, CA',
#  'Tupelo Con 2025',
#  'March 15-16, 2025',
#  'Tupelo Furniture MarketTupelo, MS',
#  'Bentonville Anime-Fest 2025',
#  'March 16, 2025',
#  'Four Points by Sheraton BentonvilleBentonville, AR',
#  'Chibi Sunny 2025',
#  'March 16, 2025',
#  'The Beacon of LightMonkwearmouth, Sunderland, UK',
#  'Cleveland Comic Book and Nostalgia Show 2025',
#  'March 16, 2025',
#  'DoubleTree by Hilton Hotel Cleveland - WestlakeWestlake, OH',
#  'Frederick Maryland Comic Con 2025',
#  'March 16, 2025',
#  'Clarion Inn Frederick Event CenterFrederick, MD',
#  'GameStorm 2025',
#  'March 20-23, 2025',
#  'DoubleTree by Hilton Hotel PortlandPortland, OR',
#  'Gary Con 2025',
#  'March 20-23, 2025',
#  'Grand Geneva Resort & SpaLake Geneva, WI',
#  'Wild Wild West Steampunk Convention 2025',
#  'March 20-23, 2025',
#  'Casino Del SolTucson, AZ',
#  'Zenkaikon 2025',
#  'March 20-23, 2025',
#  'Lancaster County Convention CenterLancaster, PA',
#  'Sci-Fi Weekender 2025',
#  'March 20-25, 2025',
#  'Vauxhall Holiday ParkGreat Yarmouth, UK',
#  'Anime Arizona 2025',
#  'March 21-23, 2025',
#  'Renaissance Phoenix Glendale Hotel & SpaGlendale, AZ',
#  'Colorado Anime Fest 2025',
#  'March 21-23, 2025',
#  'Denver Marriott Tech CenterDenver, CO',
#  'Fan Expo Cleveland 2025',
#  'March 21-23, 2025',
#  'Huntington Convention Center of ClevelandCleveland, OH',
#  'Furnal Equinox 2025',
#  'March 21-23, 2025',
#  'Westin Harbour CastleToronto, ON, Canada',
#  'HorrorHound Weekend - Cincinnati 2025',
#  'March 21-23, 2025',
#  'Sharonville Convention CenterCincinnati, OH',
#  'Isekai Anime Con 2025',
#  'March 21-23, 2025',
#  'Mountain America Exposition CenterSandy, UT',
#  'MidSouthCon 2025',
#  'March 21-23, 2025',
#  'Whispering Woods Hotel and Conference CenterOlive Branch, MS',
#  'Planet Comicon Kansas City 2025',
#  'March 21-23, 2025',
#  'Kansas City Convention CenterKansas City, MO',
#  'Shoufu-Con 2025',
#  'March 21-23, 2025',
#  'Okemos Event CenterOkemos, MI',
#  'Simcon 2025',
#  'March 21-23, 2025',
#  'University of Rochester, Frederick Douglass CommonsRochester, NY',
#  'Texas Pinball Festival 2025',
#  'March 21-23, 2025',
#  'Embassy Suites by Hilton Dallas Frisco Hotel & Convention CenterFrisco, TX',
#  'Augusta Video Gaming Exposition 2025',
#  'March 22, 2025',
#  'Augusta Elks Lodge #205Augusta, GA',
#  'Boomtown Comic Con 2025',
#  'March 22, 2025',
#  'The Dome Civic and Convention CenterBorger, TX',
#  'CarrierCon 2025',
#  'March 22, 2025',
#  'USS Hornet MuseumAlameda, CA',
#  'Dupage Comic Con 2025',
#  'March 22, 2025',
#  'Dupage County FairgroundsWheaton, IL',
#  'KingKon Comic Show 2025',
#  'March 22, 2025',
#  'APA Hotel WoodbridgeIselin, NJ',
#  'Smiths Falls ComiCon 2025',
#  'March 22, 2025',
#  'Royal Canadian Legion Branch 95Smiths Falls, ON, Canada',
#  'Wizards, Witches and the Weird 2025',
#  'March 22, 2025',
#  'The Center At DeltonaDeltona, FL',
#  'Animarathon 2025',
#  'March 22-23, 2025',
#  'Bowling Green State University, Bowen-Thompson Student UnionBowling Green, OH',
#  'Brick Fest Live Greenville 2025',
#  'March 22-23, 2025',
#  'Greenville Convention CenterGreenville, SC',
#  'CBF Isekai 2025',
#  'March 22-23, 2025',
#  'Georgia Sports Hall of FameMacon, GA',
#  'Geek Culture Con 2025',
#  'March 22-23, 2025',
#  'DoubleTree by Hilton Hotel at the Entrance to Universal OrlandoOrlando, FL',
#  'Midwest Toy and Comic Fest Springfield 2025',
#  'March 22-23, 2025',
#  'Orr BuildingSpringfield, IL',
#  'Sac Comic-Con 2025',
#  'March 22-23, 2025',
#  'SAFE Credit Union Convention CenterSacramento, CA',
#  'Salute to the Women of Sci-Fi 2025',
#  'March 22-23, 2025',
#  'Los Angeles Marriott Burbank AirportBurbank, CA',
#  'Super Retro Fest Comic Con 2025',
#  'March 22-23, 2025',
#  'DoubleTree by Hilton Hotel Boston North ShoreDanvers, MA',
#  'The Game Expo 2025',
#  'March 22-23, 2025',
#  'Melbourne Exhibition CentreMelbourne, Victoria, Australia',
#  'Tora-Con 2025',
#  'March 22-23, 2025',
#  'Rochester Institute of TechnologyRochester, NY',
#  'Anime Wild 2025',
#  'March 23, 2025',
#  'Wildwoods Convention CenterWildwood, NJ',
#  'Brockville ComiCon 2025',
#  'March 23, 2025',
#  'Brockville Memorial Civic CentreBrockville, ON, Canada',
#  'Geek/Art CONfluence 2025',
#  'March 23, 2025',
#  'Syracuse University, Schine Student CenterSyracuse, NY',
#  'HCLS Fan Fest 2025',
#  'March 23, 2025',
#  'Bay St Louis Community HallBay St Louis, MS',
#  'Preston Sci-Fi Comic & Toy Fair 2025',
#  'March 23, 2025',
#  'Macdonald Tickled Trout HotelPreston, UK',
#  'GalaxyCon Richmond 2025',
#  'March 27-30, 2025',
#  'Greater Richmond Convention CenterRichmond, VA',
#  "Nor'easter 2025",
#  'March 27-30, 2025',
#  'La Quinta Inn & Suites by Wyndham Springfield MASpringfield, MA',
#  'Big River Comic Convention 2025',
#  'March 28-29, 2025',
#  'Hannibal High School, C. Allen Korf Memorial GymnasiumHannibal, MO',
#  '90s Con CT 2025',
#  'March 28-30, 2025',
#  'Connecticut Convention CenterHartford, CT',
#  'Anime Detour 2025',
#  'March 28-30, 2025',
#  'Hyatt Regency MinneapolisMinneapolis, MN',
#  'Anime New Mexico 2025',
#  'March 28-30, 2025',
#  'Embassy Suites AlbuquerqueAlbuquerque, NM',
#  'Creature Feature Weekend 2025',
#  'March 28-30, 2025',
#  'Wyndham GettysburgGettysburg, PA',
#  'Days of the Dead Chicago 2025',
#  'March 28-30, 2025',
#  "Crowne Plaza Chicago O'Hare Hotel & Conf CtrRosemont, IL",
#  'Golden State Fur Con 2025',
#  'March 28-30, 2025',
#  'Hilton Los Angeles AirportLos Angeles, CA',
#  'Island FanCon 2025',
#  'March 28-30, 2025',
#  'City Centre ParkLangford, BC, Canada',
#  'LAN All Night 2025',
#  'March 28-30, 2025',
#  'Great Wolf Lodge Water Park | GrapevineGrapevine, TX',
#  'Motor City Furry Con 2025',
#  'March 28-30, 2025',
#  'Ann Arbor Marriott Ypsilanti at Eagle CrestYpsilanti, MI',
#  'Nadeshicon 2025',
#  'March 28-30, 2025',
#  'Centre des congrès de QuébecQuebec City, QC, Canada',
#  'Power On Con 2025',
#  'March 28-30, 2025',
#  'Weidner FieldColorado Springs, CO',
#  'Triad Anime Con 2025',
#  'March 28-30, 2025',
#  'Benton Convention CenterWinston-Salem, NC',
#  'Washington State Gaming Expo 2025',
#  'March 28-30, 2025',
#  'Washington State Fair and Events CenterPuyallup, WA',
#  'WonderCon 2025',
#  'March 28-30, 2025',
#  'Anaheim Convention CenterAnaheim, CA',
#  'ChargerCon 2025',
#  'March 29, 2025',
#  'University of Alabama in Huntsville, Conference Training CenterHuntsville, AL',
#  'Collingwood ComiCon 2025',
#  'March 29, 2025',
#  'Royal Canadian Legion Branch 63Collingwood, ON, Canada',
#  'GamePavilion.jp 2025',
#  'March 29, 2025',
#  'Umeda Sky BuildingOsaka, Japan',
#  'Portland Anime-Fest 2025',
#  'March 29, 2025',
#  'Best Western Merry Manor InnSouth Portland, ME',
#  'ScottyCon 2025',
#  'March 29, 2025',
#  'Jared L. Cohon University CenterPittsburgh, PA',
#  'Zapp Con 2025',
#  'March 29, 2025',
#  'Wayne Police Athletic League (PAL)Wayne, NJ',
#  'Anime Las Vegas 2025',
#  'March 29-30, 2025',
#  'The Expo at World Market CenterLas Vegas, NV',
#  'Brick Fest Live Landover, MD 2025',
#  'March 29-30, 2025',
#  "Prince George's Sports & Learning ComplexLandover, MD",
#  'ETSU-Con 2025',
#  'March 29-30, 2025',
#  'East Tennessee State University, D.P. Culp CenterJohnson City, TN',
#  'Lawton Super Con 2025',
#  'March 29-30, 2025',
#  'Comanche County FairgroundsLawton, OK',
#  'MegaCon Live Birmingham 2025',
#  'March 29-30, 2025',
#  'The NEC BirminghamBirmingham, UK',
#  'Mini Morphinominal 2025',
#  'March 29-30, 2025',
#  'Wonderland of the AmericasBalcones Heights, TX',
#  'Nottingham Anime & Gaming Con 2025 Cancelled',
#  'March 29-30, 2025',
#  'NTU Newton BuildingNottingham, UK',
#  'Orlando Brick Convention 2025',
#  'March 29-30, 2025',
#  'Osceola Heritage ParkKissimmee, FL',
#  'PeoriaCon 2025',
#  'March 29-30, 2025',
#  'Peoria Civic CenterPeoria, IL',
#  'QuadCon Des Moines 2025',
#  'March 29-30, 2025',
#  'Merle Hay MallDes Moines, IA',
#  'Supanova Comic-Con & Gaming - Melbourne 2025',
#  'March 29-30, 2025',
#  'Melbourne ShowgroundsMelbourne, Victoria, Australia',
#  'SwampCon 2025',
#  'March 29-30, 2025',
#  'University of Florida, J. Wayne Reitz UnionGainesville, FL',
#  'Syracuse Collectors Con 2025',
#  'March 29-30, 2025',
#  'New York State Fairgrounds, Center of Progress BuildingSyracuse, NY',
#  'Vampire Fan Weekend 2025',
#  'March 29-30, 2025',
#  'Marriott Dallas Allen Hotel & Convention CenterAllen, TX',
#  'Angus ComiCon 2025',
#  'March 30, 2025',
#  'Angus Recreation CentreAngus, ON, Canada',
#  'CardXperience Expo 2025',
#  'March 30, 2025',
#  'Scotland Community CenterChambersburg, PA',
#  'GeekSphere 2025',
#  'March 30, 2025',
#  'Centro Internacional de Convenciones ANDESan Antonio, Costa Rica',
#  'One Day Comic Expo 2025',
#  'March 30, 2025',
#  'Holiday Inn Philadelphia-Cherry HillCherry Hill, NJ',
#  'Awesome Con 2025',
#  'April 4-6, 2025',
#  'Walter E. Washington Convention CenterWashington, DC',
#  'Brickonomicon 2025',
#  'April 4-6, 2025',
#  'Hilton Knoxville AirportAlcoa, TN',
#  'Furry Down Under 2025',
#  'April 4-6, 2025',
#  'Crowne Plaza Surfers ParadiseSurfers Paradise, Queensland, Australia',
#  'Game On Expo 2025',
#  'April 4-6, 2025',
#  'Phoenix Convention CenterPhoenix, AZ',
#  'HauntFest Georgia 2025',
#  'April 4-6, 2025',
#  'Terrapin Beer Co.Athens, GA',
#  'Midwest Gaming Classic 2025',
#  'April 4-6, 2025',
#  'Baird CenterMilwaukee, WI',
#  'OKiCon Tulsa 2025',
#  'April 4-6, 2025',
#  'Marriott Tulsa Hotel Southern Hills / Ruffin Event CenterTulsa, OK',
#  'Spookala 2025',
#  'April 4-6, 2025',
#  'Florida State FairgroundsTampa, FL',
#  'Steel City Con 2025',
#  'April 4-6, 2025',
#  'Monroeville Convention CenterMonroeville, PA',
#  'Animangapop Liverpool 2025',
#  'April 5, 2025',
#  'Liverpool Guild of StudentsLiverpool, UK',
#  'CycloneCon 2025',
#  'April 5, 2025',
#  'Centenary UniversityHackettstown, NJ',
#  'Old School Comic Show 2025',
#  'April 5, 2025',
#  'Douglas N. Everett ArenaConcord, NH',
#  'Stratford ComiCon 2025',
#  'April 5, 2025',
#  'Best Western Plus The Arden Park HotelStratford, ON, Canada',
#  'Virginia Beach Anime-Fest 2025',
#  'April 5, 2025',
#  'Crowne Plaza Virginia Beach Town CenterVirginia Beach, VA',
#  'Brick Fest Live Richmond 2025',
#  'April 5-6, 2025',
#  'Greater Richmond Convention CenterRichmond, VA',
#  'Cape Anime 2025',
#  'April 5-6, 2025',
#  'Drury Plaza Hotel Cape Girardeau Conference CenterCape Girardeau, MO',
#  'Mid Valley Comic Art Expo 2025',
#  'April 5-6, 2025',
#  'Oregon State Fair & Exposition Center, Jackman-Long BuildingSalem, OR',
#  'Portsmouth Anime & Gaming Con 2025',
#  'April 5-6, 2025',
#  'Portsmouth Marriott HotelPortsmouth, UK',
#  'Salon National Des Collectionneurs 2025',
#  'April 5-6, 2025',
#  'Espace Saint-HyacintheSaint-Hyacinthe, QC, Canada',
#  'SC Comicon 2025',
#  'April 5-6, 2025',
#  'Greenville Convention CenterGreenville, SC',
#  'Southwest Comic Book and Creator Showcase 2025',
#  'April 5-6, 2025',
#  'Ramada Plaza by Wyndham Albuquerque MidtownAlbuquerque, NM',
#  'Canton-Akron Comic Book, Toy and Nostalgia Show 2025',
#  'April 6, 2025',
#  'St George Serbian Orthodox ChurchCanton, OH',
#  "Charlie's Epic Con 2025",
#  'April 6, 2025',
#  'DoubleTree by Hilton Fort Myers at Bell Tower ShopsFort Myers, FL',
#  'Kids Con New England (New Hampshire) 2025',
#  'April 6, 2025',
#  'Sheraton NashuaNashua, NH',
#  'NJIT Minicon 2025',
#  'April 6, 2025',
#  'New Jersey Institute of Technology Campus CenterNewark, NJ',
#  'Furcationland 2025',
#  'April 10-13, 2025',
#  'Holiday Inn Portland-By The BayPortland, ME',
#  'Squatchcon 2025',
#  'April 10-13, 2025',
#  'Vern Burton Community CenterPort Angeles, WA',
#  'Texas Furry Fiesta 2025',
#  'April 10-13, 2025',
#  'Sheraton Dallas HotelDallas, TX',
#  'Dairycon 2025',
#  'April 11-12, 2025',
#  'Fond du Lac County Fairgrounds, The Rec CenterFond du Lac, WI',
#  'C2E2 2025',
#  'April 11-13, 2025',
#  'McCormick PlaceChicago, IL',
#  'Costume-Con 2025',
#  'April 11-13, 2025',
#  'Hilton MilwaukeeMilwaukee, WI',
#  'Creation Boston 2025',
#  'April 11-13, 2025',
#  'The Westin Boston Seaport DistrictBoston, MA',
#  'InterGalactic ConQuest 2025',
#  'April 11-13, 2025',
#  'Scottish Rite Masonic CenterSacramento, CA',
#  'SCG Con Denver 2025',
#  'April 11-13, 2025',
#  'Colorado Convention CenterDenver, CO',
#  'Sekaicon 2025',
#  'April 11-13, 2025',
#  'Cherry Valley HotelNewark, OH',
#  'VGM Con 2025',
#  'April 11-13, 2025',
#  'Crowne Plaza Minneapolis WestPlymouth, MN',
#  'Woods Flock 2025',
#  'April 11-13, 2025',
#  'Fall Creek Falls State Park, Newton Ford Bunk Group LodgePikeville, TN',
#  'Yellow City Comic Convention 2025',
#  'April 11-13, 2025',
#  'Amarillo Civic Center ComplexAmarillo, TX',
#  'Horror Con Scotland 2025',
#  'April 12, 2025',
#  'Scottish Event CampusGlasgow, UK',
#  'Kingston ComiCon 2025',
#  'April 12, 2025',
#  'Royal Canadian Legion Branch 560Kingston, ON, Canada',
#  'Kingston Independent Comic Expo 2025',
#  'April 12, 2025',
#  'Old Dutch ChurchKingston, NY',
#  'Platform 9 3/4 Wizarding Market 2025',
#  'April 12, 2025',
#  'River City RailwayJacksonville, FL',
#  'Anime Ultra 2025',
#  'April 12-13, 2025',
#  'Rolling Oaks MallSan Antonio, TX',
#  'Anime-nia 2025',
#  'April 12-13, 2025',
#  'Fresno FairgroundsFresno, CA',
#  'Brick Fest Live Hartford 2025',
#  'April 12-13, 2025',
#  'Connecticut Convention CenterHartford, CT',
#  'Edinburgh Anime & Gaming Con 2025',
#  'April 12-13, 2025',
#  'Sheraton Grand Hotel & Spa, EdinburghEdinburgh, UK',
#  'Elfia Haarzuilens 2025',
#  'April 12-13, 2025',
#  'Castle de HaarHaarzuilens, Netherlands',
#  'Fangaea 2025',
#  'April 12-13, 2025',
#  'Handlery Hotel San DiegoSan Diego, CA',
#  'HanaCon 2025',
#  'April 12-13, 2025',
#  'CongressCentrum Wienecke XI. HannoverHannover, Germany',
#  'Midwest Toy and Comic Fest Decatur 2025',
#  'April 12-13, 2025',
#  'Decatur Civic CenterDecatur, IL',
#  'Minnesota Brick Convention 2025',
#  'April 12-13, 2025',
#  'Eagan Civic ArenaEagan, MN',
#  'Supanova Comic-Con & Gaming - Gold Coast 2025',
#  'April 12-13, 2025',
#  'Gold Coast Convention & Exhibition CentreBroadbeach, Queensland, Australia',
#  'Vaca-Con 2025',
#  'April 12-13, 2025',
#  'Ulatis Community CenterVacaville, CA',
#  'QuadCon St Charles 2025',
#  'April 13, 2025',
#  'Steel Shop Athletics & EventsSt Charles, MO',
#  'South Bend Anime-Fest 2025',
#  'April 13, 2025',
#  'Hilton Garden Inn South BendSouth Bend, IN',
#  'Las Vegas Fur Con 2025',
#  'April 17-20, 2025',
#  'Alexis Park ResortLas Vegas, NV',
#  'Anime Ottawa 2025',
#  'April 18-20, 2025',
#  'EY CentreOttawa, ON, Canada',
#  'AnthrOhio 2025',
#  'April 18-20, 2025',
#  'Hilton Columbus DowntownColumbus, OH',
#  'KokoroCon 2025',
#  'April 18-20, 2025',
#  'Crowne Plaza NottinghamNottingham, UK',
#  'Middle East Film and Comic Con 2025',
#  'April 18-20, 2025',
#  'Abu Dhabi National Exhibition Centre (ADNEC)Abu Dhabi, United Arab Emirates',
#  'Minicon 2025',
#  'April 18-20, 2025',
#  'DoubleTree by Hilton Hotel Bloomington - Minneapolis SouthBloomington, MN',
#  'MTAC 2025',
#  'April 18-20, 2025',
#  'Sheraton Music City Hotel / Embassy Suites Nashville AirportNashville, TN',
#  'Puerto Rico Comic Con 2025',
#  'April 18-20, 2025',
#  'Puerto Rico Convention CenterSan Juan, Puerto Rico',
#  'SacAnime Roseville 2025',
#  'April 18-20, 2025',
#  'Roebbelen Center @the GroundsRoseville, CA',
#  'Sakura-Con 2025',
#  'April 18-20, 2025',
#  'Seattle Convention CenterSeattle, WA',
#  'WeebCon Texas 2025',
#  'April 18-20, 2025',
#  'Irving Convention Center at Las ColinasIrving, TX',
#  'Fauntastic 2025',
#  'April 18-22, 2025',
#  'Novotel Lyon Bron EurexpoBron, France',
#  'AniFest 2025',
#  'April 19, 2025',
#  'Torrance Cultural Arts CenterTorrance, CA',
#  'Animangapop Exeter 2025',
#  'April 19, 2025',
#  'Exeter PhoenixExeter, UK',
#  'CoMo Retro Game Convention 2025',
#  'April 19, 2025',
#  'Northeast Event CenterColumbia, MO',
#  'JohnsonCity Anime-Fest 2025',
#  'April 19, 2025',
#  'Holiday Inn Johnson CityJohnson City, TN',
#  'LouisvilleCon 2025',
#  'April 19, 2025',
#  'Triple Crown PavilionLouisville, KY',
#  'Mobile Bay Anime Festival 2025',
#  'April 19, 2025',
#  'Daphne Civic CenterDaphne, AL',
#  'My-Con Spring 2025',
#  'April 19, 2025',
#  'Avanti Palms Resort and Conference CenterOrlando, FL',
#  'The AniMeet 2025',
#  'April 19, 2025',
#  'Mulungushi International Conference CentreLusaka, Zambia',
#  'Brick Fest Live Indianapolis 2025',
#  'April 19-20, 2025',
#  'Indiana Convention CenterIndianapolis, IN',
#  'Pine State Expo 2025',
#  'April 19-21, 2025',
#  'Holiday Inn by the Bay - PortlandPortland, ME',
#  'Calgary Expo 2025',
#  'April 24-27, 2025',
#  'Stampede ParkCalgary, AB, Canada',
#  'Anime St. Louis 2025',
#  'April 25-27, 2025',
#  'St. Charles Convention CenterSt. Charles, MO',
#  'DaveCon 2025',
#  'April 25-27, 2025',
#  'Crowne Plaza Suites Msp Airport - Mall of AmericaBloomington, MN',
#  'Eerie Culture Fest 2025',
#  'April 25-27, 2025',
#  'DoubleTree by Hilton Hotel Cleveland - WestlakeWestlake, OH',
#  'Huntsville Comic & Pop Culture Expo 2025',
#  'April 25-27, 2025',
#  'Von Braun CenterHuntsville, AL',
#  'iMagicon 2025',
#  'April 25-27, 2025',
#  'North Dakota State Fair CenterMinot, ND',
#  'Lvl Up Expo 2025',
#  'April 25-27, 2025',
#  'Las Vegas Convention CenterLas Vegas, NV',
#  'Rising Phoenix Game Convention 2025',
#  'April 25-27, 2025',
#  'DoubleTree by Hilton Hotel Boston - MilfordMilford, MA',
#  'The Nostalgia Con Denver 2025',
#  'April 25-27, 2025',
#  'Colorado Convention CenterDenver, CO',
#  'WizardCon 2025',
#  'April 25-27, 2025',
#  'Four Points by Sheraton KalamazooKalamazoo, MI',
#  'Furry Weekend Holland 2025',
#  'April 25-28, 2025',
#  'Kasteel de BercktBaarlo, Netherlands',
#  'Anime in the Park - Lake David Park 2025',
#  'April 26, 2025',
#  'Lake David ParkGroveland, FL',
#  'Concinnity 2025',
#  'April 26, 2025',
#  'Milwaukee School of Engineering, Dwight and Dian Diercks Computational Science HallMilwaukee, WI',
#  'Halfway 2 Halloween 2025',
#  'April 26, 2025',
#  'Marley Station MallGlen Burnie, MD',
#  'Rock & Roll Steampunk Fair 2025',
#  'April 26, 2025',
#  'Washington Borough Veterans ParkWashington, NJ',
#  'Sudbury ComiCon 2025',
#  'April 26, 2025',
#  'George Armstrong Community Centre & ArenaGreater Sudbury, ON, Canada',
#  'UmiKo 2025',
#  'April 26, 2025',
#  'Osnovna šola KoperKoper, Slovenia',
#  'Anime Tyler 2025',
#  'April 26-27, 2025',
#  'Holiday Inn Tyler - Conference CenterTyler, TX',
#  'Brick Fest Live New Jersey 2025',
#  'April 26-27, 2025',
#  'New Jersey Convention and Exposition CenterEdison, NJ',
#  'Castle Point Anime Convention 2025',
#  'April 26-27, 2025',
#  'Meadowlands Exposition CenterSecaucus, NJ',
#  'CK Expo 2025',
#  'April 26-27, 2025',
#  'Chatham-Kent John D. Bradley Convention CentreChatham, ON, Canada',
#  'Delaware Train Show & April Fools Toy Show 2025',
#  'April 26-27, 2025',
#  'Nur Shrine CenterNew Castle, DE',
#  'FicZone 2025',
#  'April 26-27, 2025',
#  'Feria de Muestras de ArmillaGranada, Spain',
#  'Game Central Station Shop & Swap 2025',
#  'April 26-27, 2025',
#  'Athens Sports ArenaAthens, GA',
#  'Manchester Anime & Gaming Con 2025',
#  'April 26-27, 2025',
#  'Sugden Sports CentreManchester, UK',
#  'Quiet Corner Sci-Fi & Comic Experience 2025',
#  'April 26-27, 2025',
#  'Woodstock Fair GroundsWoodstock, CT',
#  'Sci-Fi Scarborough 2025',
#  'April 26-27, 2025',
#  'Scarborough SpaScarborough, UK',
#  'Screamiverse Expo 2025',
#  'April 26-27, 2025',
#  'Berglund CenterRoanoke, VA',
#  'Super Jersey Comic Expo 2025',
#  'April 26-27, 2025',
#  'The Dome at Adventure CrossingJackson Township, NJ',
#  'Charleston Anime-Fest 2025',
#  'April 27, 2025',
#  'Embassy Suites by Hilton Charleston Airport Hotel & Convention CenterNorth Charleston, SC',
#  'Niagara Video Game Swap 2025',
#  'April 27, 2025',
#  'Port Dalhousie Lions ClubSt. Catharines, ON, Canada',
#  'Día del Cómic Festival 2025',
#  'May 1-4, 2025',
#  'Campo de MarteJesús María, Peru',
#  'Ibercon 2025',
#  'May 1-4, 2025',
#  'Rafaelhoteles AtochaMadrid, Spain',
#  'Montana Game Conference 2025',
#  'May 2-3, 2025',
#  'University of Montana, University CenterMissoula, MT',
#  'Anime Onsen 2025',
#  ...]

# %%
data = [{'TITLE': name,'DATE': date,'LOCATION': loc} for name, date, loc in list(zip(*[iter(events)]*3))]
data
# Out:
# [{'TITLE': 'PrezCon 2025',
#   'DATE': 'February 17-23, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel CharlottesvilleCharlottesville, VA'},
#  {'TITLE': 'NordicFuzzCon 2025',
#   'DATE': 'February 19-23, 2025',
#   'LOCATION': 'Clarion Hotel & Congress Malmö LiveMalmö, Sweden'},
#  {'TITLE': 'FurSquared 2025',
#   'DATE': 'February 20-23, 2025',
#   'LOCATION': 'Hilton Milwaukee City CenterMilwaukee, WI'},
#  {'TITLE': 'GenghisCon 2025',
#   'DATE': 'February 20-23, 2025',
#   'LOCATION': 'Hyatt Regency Aurora-Denver Conference CenterDenver, CO'},
#  {'TITLE': 'Total Confusion 2025',
#   'DATE': 'February 20-23, 2025',
#   'LOCATION': 'Best Western Royal Plaza Hotel and Trade CenterMarlborough, MA'},
#  {'TITLE': 'Bangor Anime 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Cross Insurance CenterBangor, ME'},
#  {'TITLE': 'Con Nooga 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Chattanooga Convention CenterChattanooga, TN'},
#  {'TITLE': 'Days of the Dead Atlanta 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Courtland Grand HotelAtlanta, GA'},
#  {'TITLE': 'Fan Expo Vancouver 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Vancouver Convention CentreVancouver, BC, Canada'},
#  {'TITLE': 'Great Lakes Comic Convention 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Macomb Community College Sports And Expo CenterWarren, MI'},
#  {'TITLE': 'London Anime & Gaming Con 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Novotel London WestLondon, UK'},
#  {'TITLE': 'Mad Monster Party Carolina 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Embassy Suites by Hilton Charlotte Concord Golf Resort & SpaConcord, NC'},
#  {'TITLE': 'Melbourne Furry Convention 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Novotel Melbourne PrestonPreston, Victoria, Australia'},
#  {'TITLE': 'Santiago Anthro Fest 2025',
#   'DATE': 'February 21-23, 2025',
#   'LOCATION': 'Almacruz Hotel y Centro de ConvencionesSantiago, Chile'},
#  {'TITLE': 'Animangapop Bristol 2025',
#   'DATE': 'February 22, 2025',
#   'LOCATION': 'Future Inn Bristol Cabot CircusBristol, UK'},
#  {'TITLE': 'Milwaukee Comic Con 2025',
#   'DATE': 'February 22, 2025',
#   'LOCATION': 'Wisconsin State Fairgrounds Expo Hall CWest Allis, WI'},
#  {'TITLE': 'MultiCon 2025',
#   'DATE': 'February 22, 2025',
#   'LOCATION': 'The Preserve LALos Angeles, CA'},
#  {'TITLE': 'Oshawa ComiCon 2025',
#   'DATE': 'February 22, 2025',
#   'LOCATION': 'YWCA DurhamOshawa, ON, Canada'},
#  {'TITLE': 'Tape Con 2025',
#   'DATE': 'February 22, 2025',
#   'LOCATION': 'Ozark Gateway Association of RealtorsJoplin, MO'},
#  {'TITLE': 'Alaska ComiCon 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Carlson CenterFairbanks, AK'},
#  {'TITLE': 'Brazoria County Comic Con 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Lake Jackson Civic CenterLake Jackson, TX'},
#  {'TITLE': 'Brick Fest Live Mesa 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Arizona Athletic GroundsMesa, AZ'},
#  {'TITLE': 'Bricktastic 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Manchester Central Convention ComplexManchester, UK'},
#  {'TITLE': 'Dead of Winter Horror Festival 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Mechanics HallWorcester, MA'},
#  {'TITLE': 'Goliathcon 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Central New York Family Sport CentreSyracuse, NY'},
#  {'TITLE': 'IbashoCon 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Hilton Raleigh North HillsRaleigh, NC'},
#  {'TITLE': 'Lubbock-Con 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Lubbock Memorial Civic CenterLubbock, TX'},
#  {'TITLE': 'NEPA Comic-Con 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Moon Tavern & Entertainment ComplexScranton, PA'},
#  {'TITLE': 'Texoma Comic Con 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'Choctaw Event CenterDurant, OK'},
#  {'TITLE': 'The Surrey Steampunk Convivial 2025',
#   'DATE': 'February 22-23, 2025',
#   'LOCATION': 'The StationEpsom, UK'},
#  {'TITLE': 'Comic Book & Non-Sports Card Show 2025',
#   'DATE': 'February 23, 2025',
#   'LOCATION': 'Annandale Volunteer Fire DepartmentAnnandale, VA'},
#  {'TITLE': 'Nerd Fest 2025',
#   'DATE': 'February 23, 2025',
#   'LOCATION': 'Holiday Inn Philadelphia South-SwedesboroSwedesboro, NJ'},
#  {'TITLE': 'OwlCon 2025',
#   'DATE': 'February 23, 2025',
#   'LOCATION': 'Rice University, Ley Student CenterHouston, TX'},
#  {'TITLE': 'Peterborough ComiCon 2025',
#   'DATE': 'February 23, 2025',
#   'LOCATION': 'Peterborough Curling ClubPeterborough, ON, Canada'},
#  {'TITLE': 'Simi Valley Toy and Comic Fest 2025',
#   'DATE': 'February 23, 2025',
#   'LOCATION': 'Grand Vista HotelSimi Valley, CA'},
#  {'TITLE': 'Star Trek: The Cruise 2025',
#   'DATE': 'February\xa023 - March\xa02, 2025',
#   'LOCATION': "Royal Caribbean's Explorer of the SeasDeparting from Miami, FL"},
#  {'TITLE': 'Gdakon 2025',
#   'DATE': 'February\xa026 - March\xa02, 2025',
#   'LOCATION': 'Novotel Gdansk MarinaGdańsk, Poland'},
#  {'TITLE': 'SaltCON Spring 2025',
#   'DATE': 'February\xa027 - March\xa02, 2025',
#   'LOCATION': 'Davis Conference CenterLayton, UT'},
#  {'TITLE': 'Colossalcon Cruise 2025',
#   'DATE': 'February\xa027 - March\xa03, 2025',
#   'LOCATION': "Royal Caribbean's Voyager of the SeasDeparting from Cape Canaveral, FL"},
#  {'TITLE': 'Evercon 2025',
#   'DATE': 'February\xa028 - March\xa01, 2025',
#   'LOCATION': 'Central Wisconsin Convention and Expo CenterRothschild, WI'},
#  {'TITLE': 'Gamicon 2025',
#   'DATE': 'February\xa028 - March\xa02, 2025',
#   'LOCATION': 'Hyatt Regency Coralville Hotel & Conference CenterCoralville, IA'},
#  {'TITLE': 'Horror Realm 2025',
#   'DATE': 'February\xa028 - March\xa02, 2025',
#   'LOCATION': 'Crowne Plaza Suites Pittsburgh SouthPittsburgh, PA'},
#  {'TITLE': 'LANFest Chicago x Midwest Battlegrounds 2025',
#   'DATE': 'February\xa028 - March\xa02, 2025',
#   'LOCATION': 'Sheraton Lisle Naperville HotelLisle, IL'},
#  {'TITLE': 'Lone Star Fur Con 2025',
#   'DATE': 'February\xa028 - March\xa02, 2025',
#   'LOCATION': 'Holiday Inn Austin MidtownAustin, TX'},
#  {'TITLE': 'Nerdi Gras 2025',
#   'DATE': 'February\xa028 - March\xa02, 2025',
#   'LOCATION': 'Crowne Plaza Atlanta - MidtownAtlanta, GA'},
#  {'TITLE': 'Cobourg ComiCon 2025',
#   'DATE': 'March 1, 2025',
#   'LOCATION': 'Cobourg Community CentreCobourg, ON, Canada'},
#  {'TITLE': 'Marietta the Gathering 2025',
#   'DATE': 'March 1, 2025',
#   'LOCATION': 'Marietta SquareMarietta, GA'},
#  {'TITLE': 'Orlando AnimeDay 2025',
#   'DATE': 'March 1, 2025',
#   'LOCATION': 'Sheraton Orlando North HotelMaitland, FL'},
#  {'TITLE': 'Panama City Comics Mini Con 2025',
#   'DATE': 'March 1, 2025',
#   'LOCATION': 'Bay County FairgroundsPanama City, FL'},
#  {'TITLE': 'StingrayCon 2025',
#   'DATE': 'March 1, 2025',
#   'LOCATION': 'Atlantic Coast High SchoolJacksonville, FL'},
#  {'TITLE': 'WreckCon 2025',
#   'DATE': 'March 1, 2025',
#   'LOCATION': 'Georgia Tech Exhibition Hall and Instructional CenterAtlanta, GA'},
#  {'TITLE': 'Bomb City Con 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Amarillo Civic Center ComplexAmarillo, TX'},
#  {'TITLE': 'Brick Fest Live Novi, Michigan 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Suburban Collection ShowplaceNovi, MI'},
#  {'TITLE': 'BrickUniverse Jacksonville 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Jacksonville FairgroundsJacksonville, FL'},
#  {'TITLE': 'Collect-A-Con Los Angeles 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Los Angeles Convention CenterLos Angeles, CA'},
#  {'TITLE': 'Columbia Anime & Video Game Expo 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Jamil Shrine TempleColumbia, SC'},
#  {'TITLE': 'Comic Con Scotland Aberdeen 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'P&J LiveAberdeen, UK'},
#  {'TITLE': 'Evansville Horror Con 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Old National Events PlazaEvansville, IN'},
#  {'TITLE': 'Happy Valley Comic & Collectibles Convention 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Nittany Valley Sports CentreState College, PA'},
#  {'TITLE': 'New Jersey Horror Con and Film Festival 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'New Jersey Convention and Exposition CenterEdison, NJ'},
#  {'TITLE': 'QuadCon Davenport 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'NorthPark MallDavenport, IA'},
#  {'TITLE': 'UI-Con 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'University of Illinois Urbana-Champaign, Illini UnionUrbana, IL'},
#  {'TITLE': 'Vincon 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'FoothillsFort Collins, CO'},
#  {'TITLE': 'Zolocon 2025',
#   'DATE': 'March 1-2, 2025',
#   'LOCATION': 'Valley Forge Casino ResortKing of Prussia, PA'},
#  {'TITLE': 'Furcamp 2025',
#   'DATE': 'March 1-4, 2025',
#   'LOCATION': 'Parque Estadual IntervalesRibeirão Grande, SP, Brazil'},
#  {'TITLE': 'Belleville ComiCon 2025',
#   'DATE': 'March 2, 2025',
#   'LOCATION': 'Masonic TempleBelleville, ON, Canada'},
#  {'TITLE': 'Buckeye Comic-Con 2025',
#   'DATE': 'March 2, 2025',
#   'LOCATION': 'Aladdin Shrine CenterGrove City, OH'},
#  {'TITLE': 'Fayetteville Anime-Fest 2025',
#   'DATE': 'March 2, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel FayettevilleFayetteville, NC'},
#  {'TITLE': 'Otaku Link 2025',
#   'DATE': 'March 2, 2025',
#   'LOCATION': 'The Old Bell HotelDerby, UK'},
#  {'TITLE': 'SW-FloridaCon 2025',
#   'DATE': 'March 2, 2025',
#   'LOCATION': 'DoubleTree by Hilton Fort Myers at Bell Tower ShopsFort Myers, FL'},
#  {'TITLE': 'Dark Force Fest 2025',
#   'DATE': 'March 2-4, 2025',
#   'LOCATION': 'Sheraton Parsippany HotelParsippany-Troy Hills, NJ'},
#  {'TITLE': 'JoCo Cruise 2025',
#   'DATE': 'March 2-9, 2025',
#   'LOCATION': "Holland America's ms Nieuw AmsterdamDeparting from Fort Lauderdale, FL"},
#  {'TITLE': 'Wisconsin Esports Summit 2025',
#   'DATE': 'March 3, 2025',
#   'LOCATION': 'UW-Milwaukee Panther ArenaMilwaukee, WI'},
#  {'TITLE': 'King Con Cruise 2025',
#   'DATE': 'March 3-7, 2025',
#   'LOCATION': "Royal Caribbean's Independence of the SeasDeparting from Miami, FL"},
#  {'TITLE': 'Emerald City Comic Con 2025',
#   'DATE': 'March 6-9, 2025',
#   'LOCATION': 'Seattle Convention CenterSeattle, WA'},
#  {'TITLE': 'Lexington Comic & Toy Convention 2025',
#   'DATE': 'March 6-9, 2025',
#   'LOCATION': 'Central Bank CenterLexington, KY'},
#  {'TITLE': 'VancouFur 2025',
#   'DATE': 'March 6-9, 2025',
#   'LOCATION': 'Richmond Conference CentreRichmond, BC, Canada'},
#  {'TITLE': 'Anime Milwaukee 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Baird Center / Hilton Milwaukee City CenterMilwaukee, WI'},
#  {'TITLE': 'Banzaicon 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Columbia, South CarolinaColumbia, SC'},
#  {'TITLE': 'Bewhiskered 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Sheraton Imperial Hotel Raleigh-Durham Airport at Research Triangle ParkDurham, NC'},
#  {'TITLE': 'DBZ Con Los Angeles 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Los Angeles - RosemeadRosemead, CA'},
#  {'TITLE': "Fur the 'More 2025",
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Hilton Washington Dulles AirportHerndon, VA'},
#  {'TITLE': 'Kikori Con 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Little America Hotel - FlagstaffFlagstaff, AZ'},
#  {'TITLE': 'MinamiCon 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Novotel SouthamptonSouthampton, UK'},
#  {'TITLE': 'NorthEast ComicCon & Collectibles Extravaganza 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Boxboro Regency Hotel & Conference CenterBoxborough, MA'},
#  {'TITLE': 'SCG Con Charlotte 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Charlotte Convention CenterCharlotte, NC'},
#  {'TITLE': 'TFcon Los Angeles 2025',
#   'DATE': 'March 7-9, 2025',
#   'LOCATION': 'Los Angeles Marriott Burbank AirportBurbank, CA'},
#  {'TITLE': 'Erie Anime-Fest 2025',
#   'DATE': 'March 8, 2025',
#   'LOCATION': 'Quality Inn & Suites Conference Center Across from CasinoErie, PA'},
#  {'TITLE': 'Hair of the Dragon 2025',
#   'DATE': 'March 8, 2025',
#   'LOCATION': 'Studio Space AtlantaAtlanta, GA'},
#  {'TITLE': 'Local Play 2025',
#   'DATE': 'March 8, 2025',
#   'LOCATION': 'Marley Station MallGlen Burnie, MD'},
#  {'TITLE': 'Pop Madness 2025',
#   'DATE': 'March 8, 2025',
#   'LOCATION': 'Central LibrarySan Antonio, TX'},
#  {'TITLE': 'Wilkes Comic Con 2025',
#   'DATE': 'March 8, 2025',
#   'LOCATION': 'The Stone Family Center for Performing ArtsNorth Wilkesboro, NC'},
#  {'TITLE': 'ACEcon 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Palm Harbor LibraryPalm Harbor, FL'},
#  {'TITLE': 'Bristol Anime & Gaming Con 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Mercure Bristol Grand HotelBristol, UK'},
#  {'TITLE': 'Colorado Cosmic Con 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Colorado Springs Event CenterColorado Springs, CO'},
#  {'TITLE': 'Elite_Comics11 Expo 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': "St. John's University, Taffner Field HouseQueens, NY"},
#  {'TITLE': 'FantastiCon Toledo 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Glass City CenterToledo, OH'},
#  {'TITLE': 'Louisiana Comic Con 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Cajundome Convention CenterLafayette, LA'},
#  {'TITLE': 'Midland Mall Comic Con 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Midland MallMidland, MI'},
#  {'TITLE': 'Mississippi Anime Fest 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Mississippi Trademart CenterJackson, MS'},
#  {'TITLE': 'QuadCon Madison 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'East Towne MallMadison, WI'},
#  {'TITLE': 'Raleigh Toy & Collectible Show 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'Kerr Scott BuildingRaleigh, NC'},
#  {'TITLE': 'St. Pete Comic Con 2025',
#   'DATE': 'March 8-9, 2025',
#   'LOCATION': 'The ColiseumSt. Petersburg, FL'},
#  {'TITLE': 'Ajax ComiCon 2025',
#   'DATE': 'March 9, 2025',
#   'LOCATION': 'Ajax SportsplexAjax, ON, Canada'},
#  {'TITLE': 'Clifton NJ Comic Book Expo 2025',
#   'DATE': 'March 9, 2025',
#   'LOCATION': 'Clifton Early Learning CenterClifton, NJ'},
#  {'TITLE': 'Niagara Anime-Fest 2025',
#   'DATE': 'March 9, 2025',
#   'LOCATION': 'Sheraton Niagara FallsNiagara Falls, NY'},
#  {'TITLE': 'Escape Winter Con 2025',
#   'DATE': 'March 12-16, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Orlando at SeaWorldOrlando, FL'},
#  {'TITLE': 'All-Con 2025',
#   'DATE': 'March 13-16, 2025',
#   'LOCATION': 'Hilton Dallas Lincoln CentreDallas, TX'},
#  {'TITLE': 'Huntsville Comic Con 2025',
#   'DATE': 'March 14-15, 2025',
#   'LOCATION': 'Lowe Mill ARTS & EntertainmentHuntsville, AL'},
#  {'TITLE': 'Bourbon City Steam 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Holiday Inn Louisville East - HurstbourneLouisville, KY'},
#  {'TITLE': 'Collective Con 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'The Prime F. Osborn III Convention CenterJacksonville, FL'},
#  {'TITLE': 'conAgeddon 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Boston Logan Airport HiltonBoston, MA'},
#  {'TITLE': 'EvilleCon 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Old National Events PlazaEvansville, IN'},
#  {'TITLE': 'Hauntlanta 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Lanier Islands Legacy LodgeBuford, GA'},
#  {'TITLE': 'Indiana Comic Convention 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Indianapolis Convention CenterIndianapolis, IN'},
#  {'TITLE': 'Kawaii Kon 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Hawaii Convention CenterHonolulu, HI'},
#  {'TITLE': 'Milwaukee Horror Con 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Four Points by Sheraton Milwaukee AirportMilwaukee, WI'},
#  {'TITLE': 'Monster-Mania Con 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'DoubleTree by Hilton Cherry Hill PhiladelphiaCherry Hill, NJ'},
#  {'TITLE': 'Permian Basin Comic Con 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Midland County Horseshoe ArenaMidland, TX'},
#  {'TITLE': 'Toronto Comicon 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Metro Toronto Convention CentreToronto, ON, Canada'},
#  {'TITLE': 'TsumiCon 2025',
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Alexis Park ResortLas Vegas, NV'},
#  {'TITLE': "Ve Neill's Vampire Weekend 2025",
#   'DATE': 'March 14-16, 2025',
#   'LOCATION': 'Marriott Convention CenterBurbank, CA'},
#  {'TITLE': 'Calgary Comic Book Show 2025',
#   'DATE': 'March 15, 2025',
#   'LOCATION': 'Millican Ogden Community AssociationCalgary, AB, Canada'},
#  {'TITLE': 'ClarksvilleCon 2025',
#   'DATE': 'March 15, 2025',
#   'LOCATION': 'Quality Inn Exit 4Clarksville, TN'},
#  {'TITLE': 'Indie Comics Creator Con 2025',
#   'DATE': 'March 15, 2025',
#   'LOCATION': 'Southern Connecticut State University, Adanti Student CenterNew Haven, CT'},
#  {'TITLE': 'Owen Sound ComiCon 2025',
#   'DATE': 'March 15, 2025',
#   'LOCATION': 'Royal Canadian Legion Memorial Branch 6Owen Sound, ON, Canada'},
#  {'TITLE': 'Power Comicon 2025',
#   'DATE': 'March 15, 2025',
#   'LOCATION': 'Florence CenterFlorence, SC'},
#  {'TITLE': 'Sunrise Comic Con 2025',
#   'DATE': 'March 15, 2025',
#   'LOCATION': 'Sunrise Civic CenterSunrise, FL'},
#  {'TITLE': 'BrickUniverse Waco 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'BASE at Extraco Events CenterWaco, TX'},
#  {'TITLE': 'Brighton Anime & Gaming Con 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'The Old Ship HotelBrighton, UK'},
#  {'TITLE': 'Comic, Film & Manga Fest 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Ahoy RotterdamRotterdam, Netherlands'},
#  {'TITLE': 'CT Gamer & Anime Con 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Mohegan SunUncasville, CT'},
#  {'TITLE': 'Dublin Comic Con: Spring Edition 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'The Convention Centre DublinDublin, Ireland'},
#  {'TITLE': 'Kansas Comic Con 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Century II Performing Arts & Convention CenterWichita, KS'},
#  {'TITLE': 'Paris Manga & Sci-Fi Show 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Paris Porte de VersaillesParis, France'},
#  {'TITLE': 'Pop Culture Con 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Houston CityPlace Marriott at Springwoods VillageSpring, TX'},
#  {'TITLE': 'QuadCon Omaha 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Oak View MallOmaha, NE'},
#  {'TITLE': 'San Diego Rocket Con 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Del Mar FairgroundsDel Mar, CA'},
#  {'TITLE': 'Tupelo Con 2025',
#   'DATE': 'March 15-16, 2025',
#   'LOCATION': 'Tupelo Furniture MarketTupelo, MS'},
#  {'TITLE': 'Bentonville Anime-Fest 2025',
#   'DATE': 'March 16, 2025',
#   'LOCATION': 'Four Points by Sheraton BentonvilleBentonville, AR'},
#  {'TITLE': 'Chibi Sunny 2025',
#   'DATE': 'March 16, 2025',
#   'LOCATION': 'The Beacon of LightMonkwearmouth, Sunderland, UK'},
#  {'TITLE': 'Cleveland Comic Book and Nostalgia Show 2025',
#   'DATE': 'March 16, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Cleveland - WestlakeWestlake, OH'},
#  {'TITLE': 'Frederick Maryland Comic Con 2025',
#   'DATE': 'March 16, 2025',
#   'LOCATION': 'Clarion Inn Frederick Event CenterFrederick, MD'},
#  {'TITLE': 'GameStorm 2025',
#   'DATE': 'March 20-23, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel PortlandPortland, OR'},
#  {'TITLE': 'Gary Con 2025',
#   'DATE': 'March 20-23, 2025',
#   'LOCATION': 'Grand Geneva Resort & SpaLake Geneva, WI'},
#  {'TITLE': 'Wild Wild West Steampunk Convention 2025',
#   'DATE': 'March 20-23, 2025',
#   'LOCATION': 'Casino Del SolTucson, AZ'},
#  {'TITLE': 'Zenkaikon 2025',
#   'DATE': 'March 20-23, 2025',
#   'LOCATION': 'Lancaster County Convention CenterLancaster, PA'},
#  {'TITLE': 'Sci-Fi Weekender 2025',
#   'DATE': 'March 20-25, 2025',
#   'LOCATION': 'Vauxhall Holiday ParkGreat Yarmouth, UK'},
#  {'TITLE': 'Anime Arizona 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Renaissance Phoenix Glendale Hotel & SpaGlendale, AZ'},
#  {'TITLE': 'Colorado Anime Fest 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Denver Marriott Tech CenterDenver, CO'},
#  {'TITLE': 'Fan Expo Cleveland 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Huntington Convention Center of ClevelandCleveland, OH'},
#  {'TITLE': 'Furnal Equinox 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Westin Harbour CastleToronto, ON, Canada'},
#  {'TITLE': 'HorrorHound Weekend - Cincinnati 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Sharonville Convention CenterCincinnati, OH'},
#  {'TITLE': 'Isekai Anime Con 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Mountain America Exposition CenterSandy, UT'},
#  {'TITLE': 'MidSouthCon 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Whispering Woods Hotel and Conference CenterOlive Branch, MS'},
#  {'TITLE': 'Planet Comicon Kansas City 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Kansas City Convention CenterKansas City, MO'},
#  {'TITLE': 'Shoufu-Con 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Okemos Event CenterOkemos, MI'},
#  {'TITLE': 'Simcon 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'University of Rochester, Frederick Douglass CommonsRochester, NY'},
#  {'TITLE': 'Texas Pinball Festival 2025',
#   'DATE': 'March 21-23, 2025',
#   'LOCATION': 'Embassy Suites by Hilton Dallas Frisco Hotel & Convention CenterFrisco, TX'},
#  {'TITLE': 'Augusta Video Gaming Exposition 2025',
#   'DATE': 'March 22, 2025',
#   'LOCATION': 'Augusta Elks Lodge #205Augusta, GA'},
#  {'TITLE': 'Boomtown Comic Con 2025',
#   'DATE': 'March 22, 2025',
#   'LOCATION': 'The Dome Civic and Convention CenterBorger, TX'},
#  {'TITLE': 'CarrierCon 2025',
#   'DATE': 'March 22, 2025',
#   'LOCATION': 'USS Hornet MuseumAlameda, CA'},
#  {'TITLE': 'Dupage Comic Con 2025',
#   'DATE': 'March 22, 2025',
#   'LOCATION': 'Dupage County FairgroundsWheaton, IL'},
#  {'TITLE': 'KingKon Comic Show 2025',
#   'DATE': 'March 22, 2025',
#   'LOCATION': 'APA Hotel WoodbridgeIselin, NJ'},
#  {'TITLE': 'Smiths Falls ComiCon 2025',
#   'DATE': 'March 22, 2025',
#   'LOCATION': 'Royal Canadian Legion Branch 95Smiths Falls, ON, Canada'},
#  {'TITLE': 'Wizards, Witches and the Weird 2025',
#   'DATE': 'March 22, 2025',
#   'LOCATION': 'The Center At DeltonaDeltona, FL'},
#  {'TITLE': 'Animarathon 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'Bowling Green State University, Bowen-Thompson Student UnionBowling Green, OH'},
#  {'TITLE': 'Brick Fest Live Greenville 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'Greenville Convention CenterGreenville, SC'},
#  {'TITLE': 'CBF Isekai 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'Georgia Sports Hall of FameMacon, GA'},
#  {'TITLE': 'Geek Culture Con 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel at the Entrance to Universal OrlandoOrlando, FL'},
#  {'TITLE': 'Midwest Toy and Comic Fest Springfield 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'Orr BuildingSpringfield, IL'},
#  {'TITLE': 'Sac Comic-Con 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'SAFE Credit Union Convention CenterSacramento, CA'},
#  {'TITLE': 'Salute to the Women of Sci-Fi 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'Los Angeles Marriott Burbank AirportBurbank, CA'},
#  {'TITLE': 'Super Retro Fest Comic Con 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Boston North ShoreDanvers, MA'},
#  {'TITLE': 'The Game Expo 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'Melbourne Exhibition CentreMelbourne, Victoria, Australia'},
#  {'TITLE': 'Tora-Con 2025',
#   'DATE': 'March 22-23, 2025',
#   'LOCATION': 'Rochester Institute of TechnologyRochester, NY'},
#  {'TITLE': 'Anime Wild 2025',
#   'DATE': 'March 23, 2025',
#   'LOCATION': 'Wildwoods Convention CenterWildwood, NJ'},
#  {'TITLE': 'Brockville ComiCon 2025',
#   'DATE': 'March 23, 2025',
#   'LOCATION': 'Brockville Memorial Civic CentreBrockville, ON, Canada'},
#  {'TITLE': 'Geek/Art CONfluence 2025',
#   'DATE': 'March 23, 2025',
#   'LOCATION': 'Syracuse University, Schine Student CenterSyracuse, NY'},
#  {'TITLE': 'HCLS Fan Fest 2025',
#   'DATE': 'March 23, 2025',
#   'LOCATION': 'Bay St Louis Community HallBay St Louis, MS'},
#  {'TITLE': 'Preston Sci-Fi Comic & Toy Fair 2025',
#   'DATE': 'March 23, 2025',
#   'LOCATION': 'Macdonald Tickled Trout HotelPreston, UK'},
#  {'TITLE': 'GalaxyCon Richmond 2025',
#   'DATE': 'March 27-30, 2025',
#   'LOCATION': 'Greater Richmond Convention CenterRichmond, VA'},
#  {'TITLE': "Nor'easter 2025",
#   'DATE': 'March 27-30, 2025',
#   'LOCATION': 'La Quinta Inn & Suites by Wyndham Springfield MASpringfield, MA'},
#  {'TITLE': 'Big River Comic Convention 2025',
#   'DATE': 'March 28-29, 2025',
#   'LOCATION': 'Hannibal High School, C. Allen Korf Memorial GymnasiumHannibal, MO'},
#  {'TITLE': '90s Con CT 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Connecticut Convention CenterHartford, CT'},
#  {'TITLE': 'Anime Detour 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Hyatt Regency MinneapolisMinneapolis, MN'},
#  {'TITLE': 'Anime New Mexico 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Embassy Suites AlbuquerqueAlbuquerque, NM'},
#  {'TITLE': 'Creature Feature Weekend 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Wyndham GettysburgGettysburg, PA'},
#  {'TITLE': 'Days of the Dead Chicago 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': "Crowne Plaza Chicago O'Hare Hotel & Conf CtrRosemont, IL"},
#  {'TITLE': 'Golden State Fur Con 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Hilton Los Angeles AirportLos Angeles, CA'},
#  {'TITLE': 'Island FanCon 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'City Centre ParkLangford, BC, Canada'},
#  {'TITLE': 'LAN All Night 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Great Wolf Lodge Water Park | GrapevineGrapevine, TX'},
#  {'TITLE': 'Motor City Furry Con 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Ann Arbor Marriott Ypsilanti at Eagle CrestYpsilanti, MI'},
#  {'TITLE': 'Nadeshicon 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Centre des congrès de QuébecQuebec City, QC, Canada'},
#  {'TITLE': 'Power On Con 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Weidner FieldColorado Springs, CO'},
#  {'TITLE': 'Triad Anime Con 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Benton Convention CenterWinston-Salem, NC'},
#  {'TITLE': 'Washington State Gaming Expo 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Washington State Fair and Events CenterPuyallup, WA'},
#  {'TITLE': 'WonderCon 2025',
#   'DATE': 'March 28-30, 2025',
#   'LOCATION': 'Anaheim Convention CenterAnaheim, CA'},
#  {'TITLE': 'ChargerCon 2025',
#   'DATE': 'March 29, 2025',
#   'LOCATION': 'University of Alabama in Huntsville, Conference Training CenterHuntsville, AL'},
#  {'TITLE': 'Collingwood ComiCon 2025',
#   'DATE': 'March 29, 2025',
#   'LOCATION': 'Royal Canadian Legion Branch 63Collingwood, ON, Canada'},
#  {'TITLE': 'GamePavilion.jp 2025',
#   'DATE': 'March 29, 2025',
#   'LOCATION': 'Umeda Sky BuildingOsaka, Japan'},
#  {'TITLE': 'Portland Anime-Fest 2025',
#   'DATE': 'March 29, 2025',
#   'LOCATION': 'Best Western Merry Manor InnSouth Portland, ME'},
#  {'TITLE': 'ScottyCon 2025',
#   'DATE': 'March 29, 2025',
#   'LOCATION': 'Jared L. Cohon University CenterPittsburgh, PA'},
#  {'TITLE': 'Zapp Con 2025',
#   'DATE': 'March 29, 2025',
#   'LOCATION': 'Wayne Police Athletic League (PAL)Wayne, NJ'},
#  {'TITLE': 'Anime Las Vegas 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'The Expo at World Market CenterLas Vegas, NV'},
#  {'TITLE': 'Brick Fest Live Landover, MD 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': "Prince George's Sports & Learning ComplexLandover, MD"},
#  {'TITLE': 'ETSU-Con 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'East Tennessee State University, D.P. Culp CenterJohnson City, TN'},
#  {'TITLE': 'Lawton Super Con 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'Comanche County FairgroundsLawton, OK'},
#  {'TITLE': 'MegaCon Live Birmingham 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'The NEC BirminghamBirmingham, UK'},
#  {'TITLE': 'Mini Morphinominal 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'Wonderland of the AmericasBalcones Heights, TX'},
#  {'TITLE': 'Nottingham Anime & Gaming Con 2025 Cancelled',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'NTU Newton BuildingNottingham, UK'},
#  {'TITLE': 'Orlando Brick Convention 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'Osceola Heritage ParkKissimmee, FL'},
#  {'TITLE': 'PeoriaCon 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'Peoria Civic CenterPeoria, IL'},
#  {'TITLE': 'QuadCon Des Moines 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'Merle Hay MallDes Moines, IA'},
#  {'TITLE': 'Supanova Comic-Con & Gaming - Melbourne 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'Melbourne ShowgroundsMelbourne, Victoria, Australia'},
#  {'TITLE': 'SwampCon 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'University of Florida, J. Wayne Reitz UnionGainesville, FL'},
#  {'TITLE': 'Syracuse Collectors Con 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'New York State Fairgrounds, Center of Progress BuildingSyracuse, NY'},
#  {'TITLE': 'Vampire Fan Weekend 2025',
#   'DATE': 'March 29-30, 2025',
#   'LOCATION': 'Marriott Dallas Allen Hotel & Convention CenterAllen, TX'},
#  {'TITLE': 'Angus ComiCon 2025',
#   'DATE': 'March 30, 2025',
#   'LOCATION': 'Angus Recreation CentreAngus, ON, Canada'},
#  {'TITLE': 'CardXperience Expo 2025',
#   'DATE': 'March 30, 2025',
#   'LOCATION': 'Scotland Community CenterChambersburg, PA'},
#  {'TITLE': 'GeekSphere 2025',
#   'DATE': 'March 30, 2025',
#   'LOCATION': 'Centro Internacional de Convenciones ANDESan Antonio, Costa Rica'},
#  {'TITLE': 'One Day Comic Expo 2025',
#   'DATE': 'March 30, 2025',
#   'LOCATION': 'Holiday Inn Philadelphia-Cherry HillCherry Hill, NJ'},
#  {'TITLE': 'Awesome Con 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Walter E. Washington Convention CenterWashington, DC'},
#  {'TITLE': 'Brickonomicon 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Hilton Knoxville AirportAlcoa, TN'},
#  {'TITLE': 'Furry Down Under 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Crowne Plaza Surfers ParadiseSurfers Paradise, Queensland, Australia'},
#  {'TITLE': 'Game On Expo 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Phoenix Convention CenterPhoenix, AZ'},
#  {'TITLE': 'HauntFest Georgia 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Terrapin Beer Co.Athens, GA'},
#  {'TITLE': 'Midwest Gaming Classic 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Baird CenterMilwaukee, WI'},
#  {'TITLE': 'OKiCon Tulsa 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Marriott Tulsa Hotel Southern Hills / Ruffin Event CenterTulsa, OK'},
#  {'TITLE': 'Spookala 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Florida State FairgroundsTampa, FL'},
#  {'TITLE': 'Steel City Con 2025',
#   'DATE': 'April 4-6, 2025',
#   'LOCATION': 'Monroeville Convention CenterMonroeville, PA'},
#  {'TITLE': 'Animangapop Liverpool 2025',
#   'DATE': 'April 5, 2025',
#   'LOCATION': 'Liverpool Guild of StudentsLiverpool, UK'},
#  {'TITLE': 'CycloneCon 2025',
#   'DATE': 'April 5, 2025',
#   'LOCATION': 'Centenary UniversityHackettstown, NJ'},
#  {'TITLE': 'Old School Comic Show 2025',
#   'DATE': 'April 5, 2025',
#   'LOCATION': 'Douglas N. Everett ArenaConcord, NH'},
#  {'TITLE': 'Stratford ComiCon 2025',
#   'DATE': 'April 5, 2025',
#   'LOCATION': 'Best Western Plus The Arden Park HotelStratford, ON, Canada'},
#  {'TITLE': 'Virginia Beach Anime-Fest 2025',
#   'DATE': 'April 5, 2025',
#   'LOCATION': 'Crowne Plaza Virginia Beach Town CenterVirginia Beach, VA'},
#  {'TITLE': 'Brick Fest Live Richmond 2025',
#   'DATE': 'April 5-6, 2025',
#   'LOCATION': 'Greater Richmond Convention CenterRichmond, VA'},
#  {'TITLE': 'Cape Anime 2025',
#   'DATE': 'April 5-6, 2025',
#   'LOCATION': 'Drury Plaza Hotel Cape Girardeau Conference CenterCape Girardeau, MO'},
#  {'TITLE': 'Mid Valley Comic Art Expo 2025',
#   'DATE': 'April 5-6, 2025',
#   'LOCATION': 'Oregon State Fair & Exposition Center, Jackman-Long BuildingSalem, OR'},
#  {'TITLE': 'Portsmouth Anime & Gaming Con 2025',
#   'DATE': 'April 5-6, 2025',
#   'LOCATION': 'Portsmouth Marriott HotelPortsmouth, UK'},
#  {'TITLE': 'Salon National Des Collectionneurs 2025',
#   'DATE': 'April 5-6, 2025',
#   'LOCATION': 'Espace Saint-HyacintheSaint-Hyacinthe, QC, Canada'},
#  {'TITLE': 'SC Comicon 2025',
#   'DATE': 'April 5-6, 2025',
#   'LOCATION': 'Greenville Convention CenterGreenville, SC'},
#  {'TITLE': 'Southwest Comic Book and Creator Showcase 2025',
#   'DATE': 'April 5-6, 2025',
#   'LOCATION': 'Ramada Plaza by Wyndham Albuquerque MidtownAlbuquerque, NM'},
#  {'TITLE': 'Canton-Akron Comic Book, Toy and Nostalgia Show 2025',
#   'DATE': 'April 6, 2025',
#   'LOCATION': 'St George Serbian Orthodox ChurchCanton, OH'},
#  {'TITLE': "Charlie's Epic Con 2025",
#   'DATE': 'April 6, 2025',
#   'LOCATION': 'DoubleTree by Hilton Fort Myers at Bell Tower ShopsFort Myers, FL'},
#  {'TITLE': 'Kids Con New England (New Hampshire) 2025',
#   'DATE': 'April 6, 2025',
#   'LOCATION': 'Sheraton NashuaNashua, NH'},
#  {'TITLE': 'NJIT Minicon 2025',
#   'DATE': 'April 6, 2025',
#   'LOCATION': 'New Jersey Institute of Technology Campus CenterNewark, NJ'},
#  {'TITLE': 'Furcationland 2025',
#   'DATE': 'April 10-13, 2025',
#   'LOCATION': 'Holiday Inn Portland-By The BayPortland, ME'},
#  {'TITLE': 'Squatchcon 2025',
#   'DATE': 'April 10-13, 2025',
#   'LOCATION': 'Vern Burton Community CenterPort Angeles, WA'},
#  {'TITLE': 'Texas Furry Fiesta 2025',
#   'DATE': 'April 10-13, 2025',
#   'LOCATION': 'Sheraton Dallas HotelDallas, TX'},
#  {'TITLE': 'Dairycon 2025',
#   'DATE': 'April 11-12, 2025',
#   'LOCATION': 'Fond du Lac County Fairgrounds, The Rec CenterFond du Lac, WI'},
#  {'TITLE': 'C2E2 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'McCormick PlaceChicago, IL'},
#  {'TITLE': 'Costume-Con 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'Hilton MilwaukeeMilwaukee, WI'},
#  {'TITLE': 'Creation Boston 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'The Westin Boston Seaport DistrictBoston, MA'},
#  {'TITLE': 'InterGalactic ConQuest 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'Scottish Rite Masonic CenterSacramento, CA'},
#  {'TITLE': 'SCG Con Denver 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'Colorado Convention CenterDenver, CO'},
#  {'TITLE': 'Sekaicon 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'Cherry Valley HotelNewark, OH'},
#  {'TITLE': 'VGM Con 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'Crowne Plaza Minneapolis WestPlymouth, MN'},
#  {'TITLE': 'Woods Flock 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'Fall Creek Falls State Park, Newton Ford Bunk Group LodgePikeville, TN'},
#  {'TITLE': 'Yellow City Comic Convention 2025',
#   'DATE': 'April 11-13, 2025',
#   'LOCATION': 'Amarillo Civic Center ComplexAmarillo, TX'},
#  {'TITLE': 'Horror Con Scotland 2025',
#   'DATE': 'April 12, 2025',
#   'LOCATION': 'Scottish Event CampusGlasgow, UK'},
#  {'TITLE': 'Kingston ComiCon 2025',
#   'DATE': 'April 12, 2025',
#   'LOCATION': 'Royal Canadian Legion Branch 560Kingston, ON, Canada'},
#  {'TITLE': 'Kingston Independent Comic Expo 2025',
#   'DATE': 'April 12, 2025',
#   'LOCATION': 'Old Dutch ChurchKingston, NY'},
#  {'TITLE': 'Platform 9 3/4 Wizarding Market 2025',
#   'DATE': 'April 12, 2025',
#   'LOCATION': 'River City RailwayJacksonville, FL'},
#  {'TITLE': 'Anime Ultra 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Rolling Oaks MallSan Antonio, TX'},
#  {'TITLE': 'Anime-nia 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Fresno FairgroundsFresno, CA'},
#  {'TITLE': 'Brick Fest Live Hartford 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Connecticut Convention CenterHartford, CT'},
#  {'TITLE': 'Edinburgh Anime & Gaming Con 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Sheraton Grand Hotel & Spa, EdinburghEdinburgh, UK'},
#  {'TITLE': 'Elfia Haarzuilens 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Castle de HaarHaarzuilens, Netherlands'},
#  {'TITLE': 'Fangaea 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Handlery Hotel San DiegoSan Diego, CA'},
#  {'TITLE': 'HanaCon 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'CongressCentrum Wienecke XI. HannoverHannover, Germany'},
#  {'TITLE': 'Midwest Toy and Comic Fest Decatur 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Decatur Civic CenterDecatur, IL'},
#  {'TITLE': 'Minnesota Brick Convention 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Eagan Civic ArenaEagan, MN'},
#  {'TITLE': 'Supanova Comic-Con & Gaming - Gold Coast 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Gold Coast Convention & Exhibition CentreBroadbeach, Queensland, Australia'},
#  {'TITLE': 'Vaca-Con 2025',
#   'DATE': 'April 12-13, 2025',
#   'LOCATION': 'Ulatis Community CenterVacaville, CA'},
#  {'TITLE': 'QuadCon St Charles 2025',
#   'DATE': 'April 13, 2025',
#   'LOCATION': 'Steel Shop Athletics & EventsSt Charles, MO'},
#  {'TITLE': 'South Bend Anime-Fest 2025',
#   'DATE': 'April 13, 2025',
#   'LOCATION': 'Hilton Garden Inn South BendSouth Bend, IN'},
#  {'TITLE': 'Las Vegas Fur Con 2025',
#   'DATE': 'April 17-20, 2025',
#   'LOCATION': 'Alexis Park ResortLas Vegas, NV'},
#  {'TITLE': 'Anime Ottawa 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'EY CentreOttawa, ON, Canada'},
#  {'TITLE': 'AnthrOhio 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Hilton Columbus DowntownColumbus, OH'},
#  {'TITLE': 'KokoroCon 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Crowne Plaza NottinghamNottingham, UK'},
#  {'TITLE': 'Middle East Film and Comic Con 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Abu Dhabi National Exhibition Centre (ADNEC)Abu Dhabi, United Arab Emirates'},
#  {'TITLE': 'Minicon 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Bloomington - Minneapolis SouthBloomington, MN'},
#  {'TITLE': 'MTAC 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Sheraton Music City Hotel / Embassy Suites Nashville AirportNashville, TN'},
#  {'TITLE': 'Puerto Rico Comic Con 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Puerto Rico Convention CenterSan Juan, Puerto Rico'},
#  {'TITLE': 'SacAnime Roseville 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Roebbelen Center @the GroundsRoseville, CA'},
#  {'TITLE': 'Sakura-Con 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Seattle Convention CenterSeattle, WA'},
#  {'TITLE': 'WeebCon Texas 2025',
#   'DATE': 'April 18-20, 2025',
#   'LOCATION': 'Irving Convention Center at Las ColinasIrving, TX'},
#  {'TITLE': 'Fauntastic 2025',
#   'DATE': 'April 18-22, 2025',
#   'LOCATION': 'Novotel Lyon Bron EurexpoBron, France'},
#  {'TITLE': 'AniFest 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Torrance Cultural Arts CenterTorrance, CA'},
#  {'TITLE': 'Animangapop Exeter 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Exeter PhoenixExeter, UK'},
#  {'TITLE': 'CoMo Retro Game Convention 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Northeast Event CenterColumbia, MO'},
#  {'TITLE': 'JohnsonCity Anime-Fest 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Holiday Inn Johnson CityJohnson City, TN'},
#  {'TITLE': 'LouisvilleCon 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Triple Crown PavilionLouisville, KY'},
#  {'TITLE': 'Mobile Bay Anime Festival 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Daphne Civic CenterDaphne, AL'},
#  {'TITLE': 'My-Con Spring 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Avanti Palms Resort and Conference CenterOrlando, FL'},
#  {'TITLE': 'The AniMeet 2025',
#   'DATE': 'April 19, 2025',
#   'LOCATION': 'Mulungushi International Conference CentreLusaka, Zambia'},
#  {'TITLE': 'Brick Fest Live Indianapolis 2025',
#   'DATE': 'April 19-20, 2025',
#   'LOCATION': 'Indiana Convention CenterIndianapolis, IN'},
#  {'TITLE': 'Pine State Expo 2025',
#   'DATE': 'April 19-21, 2025',
#   'LOCATION': 'Holiday Inn by the Bay - PortlandPortland, ME'},
#  {'TITLE': 'Calgary Expo 2025',
#   'DATE': 'April 24-27, 2025',
#   'LOCATION': 'Stampede ParkCalgary, AB, Canada'},
#  {'TITLE': 'Anime St. Louis 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'St. Charles Convention CenterSt. Charles, MO'},
#  {'TITLE': 'DaveCon 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'Crowne Plaza Suites Msp Airport - Mall of AmericaBloomington, MN'},
#  {'TITLE': 'Eerie Culture Fest 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Cleveland - WestlakeWestlake, OH'},
#  {'TITLE': 'Huntsville Comic & Pop Culture Expo 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'Von Braun CenterHuntsville, AL'},
#  {'TITLE': 'iMagicon 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'North Dakota State Fair CenterMinot, ND'},
#  {'TITLE': 'Lvl Up Expo 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'Las Vegas Convention CenterLas Vegas, NV'},
#  {'TITLE': 'Rising Phoenix Game Convention 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Boston - MilfordMilford, MA'},
#  {'TITLE': 'The Nostalgia Con Denver 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'Colorado Convention CenterDenver, CO'},
#  {'TITLE': 'WizardCon 2025',
#   'DATE': 'April 25-27, 2025',
#   'LOCATION': 'Four Points by Sheraton KalamazooKalamazoo, MI'},
#  {'TITLE': 'Furry Weekend Holland 2025',
#   'DATE': 'April 25-28, 2025',
#   'LOCATION': 'Kasteel de BercktBaarlo, Netherlands'},
#  {'TITLE': 'Anime in the Park - Lake David Park 2025',
#   'DATE': 'April 26, 2025',
#   'LOCATION': 'Lake David ParkGroveland, FL'},
#  {'TITLE': 'Concinnity 2025',
#   'DATE': 'April 26, 2025',
#   'LOCATION': 'Milwaukee School of Engineering, Dwight and Dian Diercks Computational Science HallMilwaukee, WI'},
#  {'TITLE': 'Halfway 2 Halloween 2025',
#   'DATE': 'April 26, 2025',
#   'LOCATION': 'Marley Station MallGlen Burnie, MD'},
#  {'TITLE': 'Rock & Roll Steampunk Fair 2025',
#   'DATE': 'April 26, 2025',
#   'LOCATION': 'Washington Borough Veterans ParkWashington, NJ'},
#  {'TITLE': 'Sudbury ComiCon 2025',
#   'DATE': 'April 26, 2025',
#   'LOCATION': 'George Armstrong Community Centre & ArenaGreater Sudbury, ON, Canada'},
#  {'TITLE': 'UmiKo 2025',
#   'DATE': 'April 26, 2025',
#   'LOCATION': 'Osnovna šola KoperKoper, Slovenia'},
#  {'TITLE': 'Anime Tyler 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Holiday Inn Tyler - Conference CenterTyler, TX'},
#  {'TITLE': 'Brick Fest Live New Jersey 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'New Jersey Convention and Exposition CenterEdison, NJ'},
#  {'TITLE': 'Castle Point Anime Convention 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Meadowlands Exposition CenterSecaucus, NJ'},
#  {'TITLE': 'CK Expo 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Chatham-Kent John D. Bradley Convention CentreChatham, ON, Canada'},
#  {'TITLE': 'Delaware Train Show & April Fools Toy Show 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Nur Shrine CenterNew Castle, DE'},
#  {'TITLE': 'FicZone 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Feria de Muestras de ArmillaGranada, Spain'},
#  {'TITLE': 'Game Central Station Shop & Swap 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Athens Sports ArenaAthens, GA'},
#  {'TITLE': 'Manchester Anime & Gaming Con 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Sugden Sports CentreManchester, UK'},
#  {'TITLE': 'Quiet Corner Sci-Fi & Comic Experience 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Woodstock Fair GroundsWoodstock, CT'},
#  {'TITLE': 'Sci-Fi Scarborough 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Scarborough SpaScarborough, UK'},
#  {'TITLE': 'Screamiverse Expo 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'Berglund CenterRoanoke, VA'},
#  {'TITLE': 'Super Jersey Comic Expo 2025',
#   'DATE': 'April 26-27, 2025',
#   'LOCATION': 'The Dome at Adventure CrossingJackson Township, NJ'},
#  {'TITLE': 'Charleston Anime-Fest 2025',
#   'DATE': 'April 27, 2025',
#   'LOCATION': 'Embassy Suites by Hilton Charleston Airport Hotel & Convention CenterNorth Charleston, SC'},
#  {'TITLE': 'Niagara Video Game Swap 2025',
#   'DATE': 'April 27, 2025',
#   'LOCATION': 'Port Dalhousie Lions ClubSt. Catharines, ON, Canada'},
#  {'TITLE': 'Día del Cómic Festival 2025',
#   'DATE': 'May 1-4, 2025',
#   'LOCATION': 'Campo de MarteJesús María, Peru'},
#  {'TITLE': 'Ibercon 2025',
#   'DATE': 'May 1-4, 2025',
#   'LOCATION': 'Rafaelhoteles AtochaMadrid, Spain'},
#  {'TITLE': 'Montana Game Conference 2025',
#   'DATE': 'May 2-3, 2025',
#   'LOCATION': 'University of Montana, University CenterMissoula, MT'},
#  {'TITLE': 'Anime Onsen 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'Colorado Springs MarriottColorado Springs, CO'},
#  {'TITLE': 'AnimeCon 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'De Broodfabriek ExpoRijswijk, Netherlands'},
#  {'TITLE': 'Crypticon Seattle 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Seattle AirportSeattle, WA'},
#  {'TITLE': 'DarknessCon: Portland 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel PortlandPortland, OR'},
#  {'TITLE': 'Farmageddon 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'American LegionFarmer City, IL'},
#  {'TITLE': 'Furgeddaboutit 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'DoubleTree Suites by Hilton Hotel Mt. LaurelMt Laurel Township, NJ'},
#  {'TITLE': 'Garden State Fur The Weekend 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'Hyatt Regency New BrunswickNew Brunswick, NJ'},
#  {'TITLE': "It's Ruff Out 2025",
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'Wildcat Mountain State ParkOntario, WI'},
#  {'TITLE': 'Nightmare Weekend Chicago 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'Donald E. Stephens Convention CenterRosemont, IL'},
#  {'TITLE': 'Otaku Oasis 2025',
#   'DATE': 'May 2-4, 2025',
#   'LOCATION': 'Hilton Dallas Lincoln CentreDallas, TX'},
#  {'TITLE': 'Barrie Comicon 2025',
#   'DATE': 'May 3, 2025',
#   'LOCATION': 'Barrie Curling ClubBarrie, ON, Canada'},
#  {'TITLE': 'Kogaracon 2025',
#   'DATE': 'May 3, 2025',
#   'LOCATION': 'Middlesex CollegeEdison, NJ'},
#  {'TITLE': 'Lehigh Valley Toys Comics & Cards Show 2025',
#   'DATE': 'May 3, 2025',
#   'LOCATION': 'Charles Chrin Community CenterPalmer Township, PA'},
#  {'TITLE': 'LTU Expo 2025',
#   'DATE': 'May 3, 2025',
#   'LOCATION': 'Lawrence Technological UniversitySouthfield, MI'},
#  {'TITLE': 'AniPop 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'California Center for the Arts, EscondidoEscondido, CA'},
#  {'TITLE': 'Cardiff Anime & Gaming Con 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': "Cardiff University, Cardiff Students' UnionCardiff, UK"},
#  {'TITLE': 'Fargo Brick Convention 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Cornerstone Bank ArenaFargo, ND'},
#  {'TITLE': 'Long Island TCG Show - Spring 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Nassau Veterans Memorial ColiseumUniondale, NY'},
#  {'TITLE': 'Maine Cosplay Extravaganza 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Portland ExpoPortland, ME'},
#  {'TITLE': 'Pixies Street Con 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Downtown YorkYork, SC'},
#  {'TITLE': 'Retro Palm Springs 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Palm Springs Convention CenterPalm Springs, CA'},
#  {'TITLE': 'Saratoga Comic Con 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Saratoga Springs City CenterSaratoga Springs, NY'},
#  {'TITLE': 'St Tammany Toy & Comic Con 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Castine CenterMandeville, LA'},
#  {'TITLE': 'Superstar Comic Con 2025',
#   'DATE': 'May 3-4, 2025',
#   'LOCATION': 'Savannah Convention CenterSavannah, GA'},
#  {'TITLE': 'Burlington Anime-Fest 2025',
#   'DATE': 'May 4, 2025',
#   'LOCATION': 'DoubleTree by Hilton Burlington VermontBurlington, VT'},
#  {'TITLE': 'Etown Anime-Fest 2025',
#   'DATE': 'May 4, 2025',
#   'LOCATION': 'Pritchard Community CenterElizabethtown, KY'},
#  {'TITLE': 'Forest Hills Comic Con 2025',
#   'DATE': 'May 4, 2025',
#   'LOCATION': 'Forest Hills High SchoolForest Hills, NY'},
#  {'TITLE': 'Furry Weekend Atlanta 2025',
#   'DATE': 'May 8-11, 2025',
#   'LOCATION': 'Atlanta Marriott MarquisAtlanta, GA'},
#  {'TITLE': 'Les Furfurieux 2025',
#   'DATE': 'May 8-11, 2025',
#   'LOCATION': 'Hotel Metz Technopole - Best Western PlusMetz, France'},
#  {'TITLE': 'PAX East 2025',
#   'DATE': 'May 8-11, 2025',
#   'LOCATION': 'Boston Convention and Exhibition CenterBoston, MA'},
#  {'TITLE': 'FrankenCon 2025',
#   'DATE': 'May 9-10, 2025',
#   'LOCATION': 'Hilton Knoxville AirportAlcoa, TN'},
#  {'TITLE': 'Anime Marathon 2025',
#   'DATE': 'May 9-11, 2025',
#   'LOCATION': 'Avalon Hotelpark KönigshofKönigslutter, Germany'},
#  {'TITLE': 'Furpile 2025',
#   'DATE': 'May 9-11, 2025',
#   'LOCATION': "Boutique Hotel's III ŁódźŁódź, Poland"},
# ...
#   'DATE': 'September 7, 2025',
#   'LOCATION': 'St George Serbian Orthodox ChurchCanton, OH'},
#  {'TITLE': 'Ancient City Con 2025',
#   'DATE': 'September 12-14, 2025',
#   'LOCATION': 'World Golf Village Renaissance St. Augustine ResortSt. Augustine, FL'},
#  {'TITLE': 'Arkansas Comic Con 2025',
#   'DATE': 'September 12-14, 2025',
#   'LOCATION': 'Statehouse Convention CenterLittle Rock, AR'},
#  {'TITLE': 'DarknessCon: Snake River 2025',
#   'DATE': 'September 12-14, 2025',
#   'LOCATION': 'Mountain View Event CenterPocatello, ID'},
#  {'TITLE': 'GalaxyCon Des Moines 2025',
#   'DATE': 'September 12-14, 2025',
#   'LOCATION': 'Iowa Events CenterDes Moines, IA'},
#  {'TITLE': 'Tidewater Horror Convention 2025',
#   'DATE': 'September 12-14, 2025',
#   'LOCATION': 'Holiday Inn Virginia Beach - NorfolkVirginia Beach, VA'},
#  {'TITLE': 'Animangapop Manchester 2025',
#   'DATE': 'September 13, 2025',
#   'LOCATION': 'Sugden Sports CentreManchester, UK'},
#  {'TITLE': 'Cartoon-A Paloozah 2025',
#   'DATE': 'September 13, 2025',
#   'LOCATION': 'Temecula Civic CenterTemecula, CA'},
#  {'TITLE': 'Chizu Con 2025',
#   'DATE': 'September 13, 2025',
#   'LOCATION': 'Goodman Community CenterMadison, WI'},
#  {'TITLE': 'Epic Mighty Con 2025',
#   'DATE': 'September 13, 2025',
#   'LOCATION': 'Wendell Community CenterWendell, NC'},
#  {'TITLE': 'Horror Fiesta 2025',
#   'DATE': 'September 13, 2025',
#   'LOCATION': 'Exposition GardensPeoria, IL'},
#  {'TITLE': 'Wisconsin Horror-Fest 2025',
#   'DATE': 'September 13, 2025',
#   'LOCATION': 'Four Points by Sheraton Milwaukee AirportMilwaukee, WI'},
#  {'TITLE': 'Frightreads Book Festival 2025',
#   'DATE': 'September 13-14, 2025',
#   'LOCATION': 'Howard County FairgroundsWest Friendship, MD'},
#  {'TITLE': 'Milton Keynes Anime & Gaming Con 2025',
#   'DATE': 'September 13-14, 2025',
#   'LOCATION': 'Leonardo Hotel Milton KeynesMilton Keynes, UK'},
#  {'TITLE': 'Quad Cities Brick Convention 2025',
#   'DATE': 'September 13-14, 2025',
#   'LOCATION': 'Mississippi Valley FairgroundsDavenport, IA'},
#  {'TITLE': 'FT-Lauderdale Anime-Fest 2025',
#   'DATE': 'September 14, 2025',
#   'LOCATION': 'Embassy Suites by Hilton Fort Lauderdale 17th StreetFort Lauderdale, FL'},
#  {'TITLE': 'Capclave 2025',
#   'DATE': 'September 19-21, 2025',
#   'LOCATION': 'Hilton Washington DC/Rockville Hotel & Executive Meeting CenterRockville, MD'},
#  {'TITLE': 'Cleveland Gaming Classic 2025',
#   'DATE': 'September 19-21, 2025',
#   'LOCATION': 'I-X CenterCleveland, OH'},
#  {'TITLE': 'Edmonton Expo 2025',
#   'DATE': 'September 19-21, 2025',
#   'LOCATION': 'Edmonton Expo CentreEdmonton, AB, Canada'},
#  {'TITLE': 'Alpha Omega Con 2025',
#   'DATE': 'September 20, 2025',
#   'LOCATION': 'Light & Life Christian FellowshipLong Beach, CA'},
#  {'TITLE': 'AshevilleCon 2025',
#   'DATE': 'September 20, 2025',
#   'LOCATION': 'Haywood Park HotelAsheville, NC'},
#  {'TITLE': 'Genderverse FurCon 2025',
#   'DATE': 'September 20, 2025',
#   'LOCATION': 'Delta Hotels Toronto Airport & Conference CentreToronto, ON, Canada'},
#  {'TITLE': 'Kentucky Horror-Fest 2025',
#   'DATE': 'September 20, 2025',
#   'LOCATION': 'Capital Plaza HotelFrankfort, KY'},
#  {'TITLE': 'Sci-Fi Day at the REME Museum 2025',
#   'DATE': 'September 20, 2025',
#   'LOCATION': 'REME MuseumLyneham, Chippenham, UK'},
#  {'TITLE': 'Anime Ultra 2025',
#   'DATE': 'September 20-21, 2025',
#   'LOCATION': 'Rolling Oaks MallSan Antonio, TX'},
#  {'TITLE': 'Follow the Yellow Gate Road 2025',
#   'DATE': 'September 20-21, 2025',
#   'LOCATION': 'Best Western Plus Bentley Hotel & SpaLincoln, UK'},
#  {'TITLE': 'Granite State Comicon 2025',
#   'DATE': 'September 20-21, 2025',
#   'LOCATION': 'DoubleTree by Hilton Manchester Downtown / SNHU ArenaManchester, NH'},
#  {'TITLE': 'HorrorCon Los Angeles 2025',
#   'DATE': 'September 20-21, 2025',
#   'LOCATION': 'Los Angeles Convention CenterLos Angeles, CA'},
#  {'TITLE': 'SC Horror Convention 2025',
#   'DATE': 'September 20-21, 2025',
#   'LOCATION': 'Columbia Metropolitan Convention CenterColumbia, SC'},
#  {'TITLE': 'Northern KY Anime-Fest 2025',
#   'DATE': 'September 21, 2025',
#   'LOCATION': 'Marriott Cincinnati AirportHebron, KY'},
#  {'TITLE': 'FanX Salt Lake Comic Convention 2025',
#   'DATE': 'September 25-27, 2025',
#   'LOCATION': 'Salt Palace Convention CenterSalt Lake City, UT'},
#  {'TITLE': 'Furdance Budapest 2025',
#   'DATE': 'September 26-28, 2025',
#   'LOCATION': 'Csokonai Kulturális KözpontBudapest, Hungary'},
#  {'TITLE': 'Furry Takeover 2025',
#   'DATE': 'September 26-28, 2025',
#   'LOCATION': 'Fontana Village Resort & MarinaFontana Dam, NC'},
#  {'TITLE': 'L.A. Comic Con 2025',
#   'DATE': 'September 26-28, 2025',
#   'LOCATION': 'Los Angeles Convention CenterLos Angeles, CA'},
#  {'TITLE': 'Morgue and Krypt Horror Fest 2025',
#   'DATE': 'September 26-28, 2025',
#   'LOCATION': 'Isleta Resort & CasinoAlbuquerque, NM'},
#  {'TITLE': 'Rappig Crossing 2025',
#   'DATE': 'September 26-28, 2025',
#   'LOCATION': 'Wyndham Indianapolis WestIndianapolis, IN'},
#  {'TITLE': 'The Nostalgia Con Milwaukee 2025',
#   'DATE': 'September 26-28, 2025',
#   'LOCATION': 'Baird CenterMilwaukee, WI'},
#  {'TITLE': 'Florida Horror-Fest 2025',
#   'DATE': 'September 27, 2025',
#   'LOCATION': 'DoubleTree by Hilton Fort Myers at Bell Tower ShopsFort Myers, FL'},
#  {'TITLE': 'Kingston ComiCon 2025',
#   'DATE': 'September 27, 2025',
#   'LOCATION': 'Royal Canadian Legion Branch 560Kingston, ON, Canada'},
#  {'TITLE': 'AnimeVerse Reno 2025',
#   'DATE': 'September 27-28, 2025',
#   'LOCATION': 'Silver Legacy Resort CasinoReno, NV'},
#  {'TITLE': 'Belfast Anime & Gaming Con 2025',
#   'DATE': 'September 27-28, 2025',
#   'LOCATION': 'Crowne Plaza BelfastBelfast, UK'},
#  {'TITLE': 'Chattanooga Comic Con 2025',
#   'DATE': 'September 27-28, 2025',
#   'LOCATION': 'Chattanooga Convention CenterChattanooga, TN'},
#  {'TITLE': 'NorCon 2025',
#   'DATE': 'September 27-28, 2025',
#   'LOCATION': 'Norfolk Showground ArenaNorwich, UK'},
#  {'TITLE': 'South Alabama Comic Con 2025',
#   'DATE': 'September 27-28, 2025',
#   'LOCATION': 'Mobile Convention CenterMobile, AL'},
#  {'TITLE': 'Zurich Pop Con & Game Show 2025',
#   'DATE': 'September 27-28, 2025',
#   'LOCATION': 'Messe ZürichZürich, Switzerland'},
#  {'TITLE': 'St.Louis Anime-Fest 2025',
#   'DATE': 'September 28, 2025',
#   'LOCATION': 'Holiday Inn St. Louis - Downtown Conv CtrSt. Louis, MO'},
#  {'TITLE': 'AmeChibi 2025',
#   'DATE': 'October 3-5, 2025',
#   'LOCATION': 'Mercure NorthamptonNorthampton, UK'},
#  {'TITLE': 'Animate! Philadelphia 2025',
#   'DATE': 'October 3-5, 2025',
#   'LOCATION': 'The Greater Philadelphia Expo CenterOaks, PA'},
#  {'TITLE': 'Anime Fiesta 2025',
#   'DATE': 'October 3-5, 2025',
#   'LOCATION': 'McAllen Convention CenterMcAllen, TX'},
#  {'TITLE': 'Central PA Tattoo and Horror Expo 2025',
#   'DATE': 'October 3-5, 2025',
#   'LOCATION': 'Hollywood Casino at Penn National Race CourseGrantville, PA'},
#  {'TITLE': 'Carolinas Horror-Fest 2025',
#   'DATE': 'October 4, 2025',
#   'LOCATION': 'Haywood Park HotelAsheville, NC'},
#  {'TITLE': 'NC Disneyana 2025',
#   'DATE': 'October 4, 2025',
#   'LOCATION': 'Millennium Hotel DurhamDurham, NC'},
#  {'TITLE': 'Anime Sekai 2025',
#   'DATE': 'October 4-5, 2025',
#   'LOCATION': 'Abilene Convention CenterAbilene, TX'},
#  {'TITLE': 'Brick Fest Live Rochester 2025',
#   'DATE': 'October 4-5, 2025',
#   'LOCATION': 'Joseph A. Floreano Rochester Riverside Convention CenterRochester, NY'},
#  {'TITLE': 'Newcastle Anime & Gaming Con 2025',
#   'DATE': 'October 4-5, 2025',
#   'LOCATION': 'Event NorthumbriaNewcastle, UK'},
#  {'TITLE': 'ToonFusion Oklahoma 2025',
#   'DATE': 'October 4-5, 2025',
#   'LOCATION': 'Cox Business Convention CenterTulsa, OK'},
#  {'TITLE': 'Aurora ComiCon 2025',
#   'DATE': 'October 5, 2025',
#   'LOCATION': 'Aurora Royal Canadian Legion Branch 385Aurora, ON, Canada'},
#  {'TITLE': 'Cleveland Comic Book and Nostalgia Show 2025',
#   'DATE': 'October 5, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Cleveland - WestlakeWestlake, OH'},
#  {'TITLE': 'Niagara Game Con 2025',
#   'DATE': 'October 5, 2025',
#   'LOCATION': 'Merritton Community CentreSt. Catharines, ON, Canada'},
#  {'TITLE': 'Battle Barge 2025',
#   'DATE': 'October 5-11, 2025',
#   'LOCATION': 'Royal Caribbean Harmony of the SeasDeparting from Galveston, TX'},
#  {'TITLE': 'Alamo City Furry Invasion 2025',
#   'DATE': 'October 9-12, 2025',
#   'LOCATION': 'Embassy Suites by Hilton San Marcos Hotel Conference CenterSan Marcos, TX'},
#  {'TITLE': 'New York Comic Con 2025',
#   'DATE': 'October 9-12, 2025',
#   'LOCATION': 'Jacob K. Javits CenterNew York, NY'},
#  {'TITLE': 'Anime USA 2025',
#   'DATE': 'October 10-12, 2025',
#   'LOCATION': 'Hyatt Regency Crystal City At Reagan National AirportArlington, VA'},
#  {'TITLE': 'ConQuest Avalon 2025',
#   'DATE': 'October 10-12, 2025',
#   'LOCATION': 'Scottish Rite Masonic CenterSacramento, CA'},
#  {'TITLE': 'GalaxyCon St. Louis 2025',
#   'DATE': 'October 10-12, 2025',
#   'LOCATION': "America's CenterSt. Louis, MO"},
#  {'TITLE': 'Oni-Con 2025',
#   'DATE': 'October 10-12, 2025',
#   'LOCATION': 'Galveston Island Convention Center at The San Luis ResortGalveston, TX'},
#  {'TITLE': 'Tsubasacon 2025',
#   'DATE': 'October 10-12, 2025',
#   'LOCATION': 'Charleston Coliseum & Convention CenterCharleston, WV'},
#  {'TITLE': 'Richmond Anime-Fest 2025',
#   'DATE': 'October 11, 2025',
#   'LOCATION': 'Four Points by Sheraton Richmond AirportRichmond, VA'},
#  {'TITLE': 'Missouri Anime Fest 2025',
#   'DATE': 'October 11-12, 2025',
#   'LOCATION': 'Springfield Expo CenterSpringfield, MO'},
#  {'TITLE': 'Missouri Horror-Fest 2025',
#   'DATE': 'October 12, 2025',
#   'LOCATION': 'Holiday Inn St. Louis - Downtown Convention CenterSt. Louis, MO'},
#  {'TITLE': 'Carlisle Comic Con 2025',
#   'DATE': 'October 17-18, 2025',
#   'LOCATION': 'Carlisle Expo CenterCarlisle, PA'},
#  {'TITLE': 'Anime Fusion 2025',
#   'DATE': 'October 17-19, 2025',
#   'LOCATION': 'Crowne Plaza Minneapolis WestPlymouth, MN'},
#  {'TITLE': 'Beaumont Comic Con 2025',
#   'DATE': 'October 17-19, 2025',
#   'LOCATION': 'Ford ArenaBeaumont, TX'},
#  {'TITLE': 'MiraiCon 2025',
#   'DATE': 'October 17-19, 2025',
#   'LOCATION': 'Fort Lauderdale Marriott Coral Springs Hotel & Convention CenterCoral Springs, FL'},
#  {'TITLE': 'Nightmare Weekend Richmond 2025',
#   'DATE': 'October 17-19, 2025',
#   'LOCATION': 'Greater Richmond Convention CenterRichmond, VA'},
#  {'TITLE': 'Portland Retro Gaming Expo 2025',
#   'DATE': 'October 17-19, 2025',
#   'LOCATION': 'Oregon Convention CenterPortland, OR'},
#  {'TITLE': 'Irish Discworld Convention 2025',
#   'DATE': 'October 17-20, 2025',
#   'LOCATION': 'Cork International HotelCork, Ireland'},
#  {'TITLE': 'ClarksvilleCon Fall 2025',
#   'DATE': 'October 18, 2025',
#   'LOCATION': 'Quality Inn Exit 4Clarksville, TN'},
#  {'TITLE': 'Georgia Horror-Fest 2025',
#   'DATE': 'October 18, 2025',
#   'LOCATION': 'Columbia County Exhibition CenterGrovetown, GA'},
#  {'TITLE': 'Inferno Fest 2025',
#   'DATE': 'October 18, 2025',
#   'LOCATION': 'Denton Civic CenterDenton, TX'},
#  {'TITLE': 'Bowling Green Anime-Fest 2025',
#   'DATE': 'October 19, 2025',
#   'LOCATION': 'National Corvette MuseumBowling Green, KY'},
#  {'TITLE': 'Mobidictum Conference 2025',
#   'DATE': 'October 21-22, 2025',
#   'LOCATION': 'Istanbul Lutfi Kirdar International Convention & Exhibition CenterIstanbul, Turkey'},
#  {'TITLE': 'Washington State Horror Con 2025',
#   'DATE': 'October 24-26, 2025',
#   'LOCATION': 'Washington State Fair and Events CenterPuyallup, WA'},
#  {'TITLE': 'Alabama Horror-Fest 2025',
#   'DATE': 'October 25, 2025',
#   'LOCATION': 'Dothan City Civic CenterDothan, AL'},
#  {'TITLE': 'Lafayette Comic Con 2025',
#   'DATE': 'October 25, 2025',
#   'LOCATION': 'Tippecanoe County FairgroundsLafayette, IN'},
#  {'TITLE': 'Oshawa ComiCon 2025',
#   'DATE': 'October 25, 2025',
#   'LOCATION': 'YWCA DurhamOshawa, ON, Canada'},
#  {'TITLE': 'Tennessee Horror-Fest 2025',
#   'DATE': 'October 25, 2025',
#   'LOCATION': 'Quality Inn Exit 4Clarksville, TN'},
#  {'TITLE': 'Retro Planet 2025',
#   'DATE': 'October 25-26, 2025',
#   'LOCATION': 'Fort Bend County EpicenterRosenberg, TX'},
#  {'TITLE': 'Furry Blacklight 2025',
#   'DATE': 'October\xa029 - November\xa02, 2025',
#   'LOCATION': 'H4 Hotel Wyndham Paris Pleyel ResortSaint-Denis, France'},
#  {'TITLE': 'Reffurence 2025',
#   'DATE': 'October\xa030 - November\xa02, 2025',
#   'LOCATION': 'Hotel ZuiderduinEgmond aan Zee, Netherlands'},
#  {'TITLE': 'VillainSCon 2025',
#   'DATE': 'October\xa031 - November\xa01, 2025',
#   'LOCATION': 'The Power HouseRock Hill, SC'},
#  {'TITLE': 'DerpyCon 2025',
#   'DATE': 'October\xa031 - November\xa02, 2025',
#   'LOCATION': 'Hyatt Regency New BrunswickNew Brunswick, NJ'},
#  {'TITLE': 'Heroes Comic Con Stockholm Winter 2025',
#   'DATE': 'October\xa031 - November\xa02, 2025',
#   'LOCATION': 'StockholmsmässanÄlvsjö, Sweden'},
#  {'TITLE': 'Kumoricon 2025',
#   'DATE': 'October\xa031 - November\xa02, 2025',
#   'LOCATION': 'Oregon Convention CenterPortland, OR'},
#  {'TITLE': 'Nekocon 2025',
#   'DATE': 'October\xa031 - November\xa02, 2025',
#   'LOCATION': 'Hampton Roads Convention CenterHampton, VA'},
#  {'TITLE': 'Supanova Comic Con & Gaming - Adelaide 2025',
#   'DATE': 'October\xa031 - November\xa02, 2025',
#   'LOCATION': 'Adelaide ShowgroundWayville, South Australia, Australia'},
#  {'TITLE': 'Waifucon 2025',
#   'DATE': 'October\xa031 - November\xa02, 2025',
#   'LOCATION': 'Hilton Birmingham Downtown at UABBirmingham, AL'},
#  {'TITLE': 'Animangapop Brighton 2025',
#   'DATE': 'November 1, 2025',
#   'LOCATION': 'Holiday Inn Brighton - SeafrontBrighton, UK'},
#  {'TITLE': 'Cleveland Anime-Fest 2025',
#   'DATE': 'November 1, 2025',
#   'LOCATION': 'Wyndham Garden WestlakeWestlake, OH'},
#  {'TITLE': 'Pulp Adventurecon 2025',
#   'DATE': 'November 1, 2025',
#   'LOCATION': 'Sheraton Bucks County LanghorneLanghorne, PA'},
#  {'TITLE': 'SoCo Horror Con 2025',
#   'DATE': 'November 1, 2025',
#   'LOCATION': 'Colorado State Fairgrounds, CSU PavillionPueblo, CO'},
#  {'TITLE': 'Sonic Con UK London 2025',
#   'DATE': 'November 1, 2025',
#   'LOCATION': 'Novotel London WestLondon, UK'},
#  {'TITLE': 'Anime Ultra 2025',
#   'DATE': 'November 1-2, 2025',
#   'LOCATION': 'Rolling Oaks MallSan Antonio, TX'},
#  {'TITLE': 'Southampton Anime & Gaming Con 2025',
#   'DATE': 'November 1-2, 2025',
#   'LOCATION': 'Novotel SouthamptonSouthampton, UK'},
#  {'TITLE': 'Baycon 2025',
#   'DATE': 'November 2, 2025',
#   'LOCATION': 'Franklin Elks Lodge #2136Franklin, MA'},
#  {'TITLE': 'TeslaCon 2025',
#   'DATE': 'November 6-9, 2025',
#   'LOCATION': 'Madison Marriott WestMiddleton, WI'},
#  {'TITLE': 'HotaruCon 2025',
#   'DATE': 'November 7-9, 2025',
#   'LOCATION': 'Leonardo Hotel Milton KeynesMilton Keynes, UK'},
#  {'TITLE': 'Rhode Island Comic Con 2025',
#   'DATE': 'November 7-9, 2025',
#   'LOCATION': 'Rhode Island Convention CenterProvidence, RI'},
#  {'TITLE': 'Supanova Comic Con & Gaming - Brisbane 2025',
#   'DATE': 'November 7-9, 2025',
#   'LOCATION': 'Brisbane Convention & Exhibition CentreSouth Brisbane, Queensland, Australia'},
#  {'TITLE': 'Sheffield Anime & Gaming Con 2025',
#   'DATE': 'November 8-9, 2025',
#   'LOCATION': "Mercure Sheffield St Paul's Hotel & SpaSheffield, UK"},
#  {'TITLE': 'Peterborough ComiCon 2025',
#   'DATE': 'November 9, 2025',
#   'LOCATION': 'Peterborough Curling ClubPeterborough, ON, Canada'},
#  {'TITLE': 'GoldenHorn 2025',
#   'DATE': 'November 13-16, 2025',
#   'LOCATION': 'Adria Ankaran Hotel & ResortAnkaran, Slovenia'},
#  {'TITLE': 'Nightmare Weekend Savannah 2025',
#   'DATE': 'November 14-16, 2025',
#   'LOCATION': 'Savannah Convention CenterSavannah, GA'},
#  {'TITLE': 'Queen City Expo 2025',
#   'DATE': 'November 14-16, 2025',
#   'LOCATION': 'Cross Insurance CenterBangor, ME'},
#  {'TITLE': 'Kids Con New England (Maine) 2025',
#   'DATE': 'November 15, 2025',
#   'LOCATION': 'DoubleTree by Hilton Hotel Portland, MESouth Portland, ME'},
#  {'TITLE': 'Anime Impulse Dallas 2025',
#   'DATE': 'November 15-16, 2025',
#   'LOCATION': 'Kay Bailey Hutchison Convention Center DallasDallas, TX'},
#  {'TITLE': 'Brick Fest Live St. Louis 2025',
#   'DATE': 'November 15-16, 2025',
#   'LOCATION': 'Gateway Convention CenterCollinsville, IL'},
#  {'TITLE': 'Fresno Comic Expo 2025',
#   'DATE': 'November 15-16, 2025',
#   'LOCATION': 'Fresno Convention & Entertainment CenterFresno, CA'}]

# %%
#requests.post(url = 'http://127.0.0.1:5000/events/save',json = data)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10c023bd0>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /events/save (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10c023bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 requests.post(url = 'http://127.0.0.1:5000/events/save',json = data)
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/GitHub/Event-Aggregator/.venv/lib/python3.11/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /events/save (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10c023bd0>: Failed to establish a new connection: [Errno 61] Connection refused'))
