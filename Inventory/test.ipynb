# %%
import pandas as pd
import os

# %%
# Had to convert the empty strings to a single space becuase pandas was reading it in and replacing it with a null value

# %%
df = pd.read_csv('events.csv',index_col=0)
print(df.shape)
df.info()
df.head()
# Out:
# (182, 14)
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        182 non-null    object
#  1   tags         182 non-null    object
#  2   description  182 non-null    object
#  3   likes        182 non-null    int64
#  4   event type   182 non-null    object
#  5   price        182 non-null    float64
#  6   date         182 non-null    object
#  7   address1     182 non-null    object
#  8   address2     182 non-null    object
#  9   city         182 non-null    object
#  10  state        182 non-null    object
#  11  zipcode      182 non-null    int64
#  12  lat          182 non-null    float64
#  13  lng          182 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 21.3+ KB
#                                    title  \
# 0                    Monster Hunter Rise
# ...

# %%
# Having issues eval because of the 'address2': null. Needs to be filled in with a string first
df.fillna(value = ' ',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        182 non-null    object
#  1   tags         182 non-null    object
#  2   description  182 non-null    object
#  3   likes        182 non-null    int64
#  4   event type   182 non-null    object
#  5   price        182 non-null    float64
#  6   date         182 non-null    object
#  7   address1     182 non-null    object
#  8   address2     182 non-null    object
#  9   city         182 non-null    object
#  10  state        182 non-null    object
#  11  zipcode      182 non-null    int64
#  12  lat          182 non-null    float64
#  13  lng          182 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 21.3+ KB

# %%
eval(df.sample(n = 1).to_json(orient='records'))[0]
# Out:
# {'title': 'Shin Megami Tensei V',
#  'tags': "['Adventure', 'RPG', 'Turn Based Strategy']",
#  'description': 'Shin Megami Tensei V, the fifth numbered game of the Shin Megami Tensei series, is a role-playing video game set in modern-day Tokyo. It will feature returning gameplay elements from previous games, such as the ability to fuse demons, along with new mechanics.',
#  'likes': 13,
#  'event type': 'Special Event',
#  'price': 0.0,
#  'date': '2025-06-02 20:06:00',
#  'address1': '1917 Whitaker Street',
#  'address2': '',
#  'city': 'Savannah',
#  'state': 'GA',
#  'zipcode': 31401,
#  'lat': 32.0585396,
#  'lng': -81.1009886}

# %%
df.to_csv('events.csv',index_label=False)

# %%
df.drop_duplicates(subset='title',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df.drop_duplicates(subset='title',inplace=True).info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
title_to_search = 'monster hunter rise'
#df['title'].apply(func = lambda s: s.lower()).to_frame().query(f'title == "{title_to_search}"').iloc[0]
for _ in range(20):
    output = df[df['title'].apply(func = lambda s: s.lower()) == title_to_search].sample().to_json(orient='records')
    print(_,output)
    print(eval(output))
# Out:
# 0 [{"title":"Monster Hunter Rise","tags":"['Adventure', 'Brawler', 'RPG']","description":"Rise to the challenge and join the hunt! In Monster Hunter Rise, the latest installment in the award-winning and top-selling Monster Hunter series, you\u00e2\u20ac\u2122ll become a hunter, explore brand new maps and use a variety of weapons to take down fearsome monsters as part of an all-new storyline.","likes":0,"event type":"Sport - Adult","price":24.99,"date":"2025-04-21 19:23:00","address1":"1217 Bay Street","address2":"#318-A","city":"Tybee Island","state":"GA","zipcode":31328,"lat":32.0222005,"lng":-80.8587482}]
# ...

# %%
df.sample(n = 1, weights=df['likes'])
# Out:
#                               title                             tags  \
# 116  Fire Emblem: The Blazing Blade  ['RPG', 'Strategy', 'Tactical']
#
#                                            description  likes     event type  \
# 116  It is the seventh game of the Fire Emblem seri...     53  Sport - Adult
#
#      price                 date                 address1 address2        city  \
# 116   0.99  2025-11-23 21:35:00  1426 C Street Southeast      NaN  Washington
#
#     state  zipcode        lat        lng
# 116    DC    20003  38.885654 -76.984601
