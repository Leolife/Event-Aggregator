# %%
import pandas as pd

# %%
df = pd.read_csv('Final_Events.csv')
# Out:
#                   Title                                               Desc  \
# 0      PGL Wallachia S3  Full information about PGL Wallachia S3 Dota 2...
# 1         BLAST Slam #3  Full information about BLAST Slam #3 Dota 2. M...
# 2  ESL One Raleigh 2025  Full information about ESL One Raleigh 2025 Do...
# 3      PGL Wallachia S4  Full information about PGL Wallachia S4 Dota 2...
# 4              Dota Duo  Find tickets for Dota at Weingut Karl Sonntag ...
#
#   Start Date                                      When  \
# 0      Mar 8                                Sat, Mar 8
# 1      May 5                                Mon, May 5
# 2      Apr 6  Sun, Apr 6, 8 PM – Sat, Apr 12, 8 PM EDT
# 3     Apr 19                               Sat, Apr 19
# 4     Jul 27               Sun, Jul 27, 7 – 8 PM GMT+2
#
#                                            Main Page  \
# 0  https://ggscore.com/en/dota-2/pgl-wallachia-se...
# 1         https://ggscore.com/en/dota-2/blast-slam-3
# ...

# %%
df['image']
# Out:
# 0      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3      https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4      https://encrypted-tbn0.gstatic.com/images?q=tb...
#                              ...
# 484    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 485    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 486    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 487    https://encrypted-tbn0.gstatic.com/images?q=tb...
# 488    https://encrypted-tbn0.gstatic.com/images?q=tb...
# Name: image, Length: 489, dtype: object
